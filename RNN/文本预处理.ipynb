# %% [markdown]
# - 将文本作为字符串加载到内存中。
# - 将字符串拆分为词元（如单词和字符）。
# - 建立一个词表，将拆分的词元映射到数字索引。
# - 将文本转换为数字索引序列，方便模型操作。

# %%
import collections
import re
from d2l import torch as d2l

# %% [markdown]
# 读取数据集，按行存到lines中

# %%
d2l.DATA_HUB['time_machine'] = (d2l.DATA_URL + 'timemachine.txt',
                                '090b5e7e70c295757f55df93cb0a180b9691891a')

# %%
def read_time_machine():
    with open(d2l.download('time_machine'), 'r') as f:
        lines = f.readlines()
    return [re.sub('[^A-Za-x]+', ' ', line).strip().lower() for line in lines]

lines = read_time_machine()
print(f'文本总行数：{len(lines)}')
test = lines[:10]
test
# Out:
# Downloading ..\data\timemachine.txt from http://d2l-data.s3-accelerate.amazonaws.com/timemachine.txt...
# 文本总行数：3221
# ['the time machine b h g wells',
#  '',
#  '',
#  '',
#  '',
#  'i',
#  '',
#  '',
#  'the time traveller for so it will be convenient to speak of him',
#  'was expounding a recondite matter to us his gre e es shone and']

# %% [markdown]
# 输入将文本行列表lines，输出为词元（token）——文本的基本单位
# 返回词元二维列表（每个词元是一个string）

# %%
def tokenize(lines, token='word'): # 提供两种分词模式
    if token == 'word':
        return [line.split() for line in lines] # 将每个line中的每个单词分离开 每行作为一个列表 生成一个二维列表
    elif token == 'char':
        return [list(line) for line in lines]
    else:
        print('错误：未知词元类型: '+ token)

tokens = tokenize(lines, token='word')
tokens
# Out:
# [['the', 'time', 'machine', 'b', 'h', 'g', 'wells'],
#  [],
#  [],
#  [],
#  [],
#  ['i'],
#  [],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'for',
#   'so',
#   'it',
#   'will',
#   'be',
#   'convenient',
#   'to',
#   'speak',
#   'of',
#   'him'],
#  ['was',
#   'expounding',
#   'a',
#   'recondite',
#   'matter',
#   'to',
#   'us',
#   'his',
#   'gre',
#   'e',
#   'es',
#   'shone',
#   'and'],
#  ['twinkled',
#   'and',
#   'his',
#   'usuall',
#   'pale',
#   'face',
#   'was',
#   'flushed',
#   'and',
#   'animated',
#   'the'],
#  ['fire',
#   'burned',
#   'brightl',
#   'and',
#   'the',
#   'soft',
#   'radiance',
#   'of',
#   'the',
#   'incandescent'],
#  ['lights',
#   'in',
#   'the',
#   'lilies',
#   'of',
#   'silver',
#   'caught',
#   'the',
#   'bubbles',
#   'that',
#   'flashed',
#   'and'],
#  ['passed',
#   'in',
#   'our',
#   'glasses',
#   'our',
#   'chairs',
#   'being',
#   'his',
#   'patents',
#   'embraced',
#   'and'],
#  ['caressed',
#   'us',
#   'rather',
#   'than',
#   'submitted',
#   'to',
#   'be',
#   'sat',
#   'upon',
#   'and',
#   'there',
#   'was',
#   'that'],
#  ['luxurious',
#   'after',
#   'dinner',
#   'atmosphere',
#   'when',
#   'thought',
#   'roams',
#   'gracefull'],
#  ['free',
#   'of',
#   'the',
#   'trammels',
#   'of',
#   'precision',
#   'and',
#   'he',
#   'put',
#   'it',
#   'to',
#   'us',
#   'in',
#   'this'],
#  ['wa',
#   'marking',
#   'the',
#   'points',
#   'with',
#   'a',
#   'lean',
#   'forefinger',
#   'as',
#   'we',
#   'sat',
#   'and',
#   'la',
#   'il'],
#  ['admired',
#   'his',
#   'earnestness',
#   'over',
#   'this',
#   'new',
#   'paradox',
#   'as',
#   'we',
#   'thought',
#   'it'],
#  ['and', 'his', 'fecundit'],
#  [],
#  ['you',
#   'must',
#   'follow',
#   'me',
#   'carefull',
#   'i',
#   'shall',
#   'have',
#   'to',
#   'controvert',
#   'one',
#   'or',
#   'two'],
#  ['ideas',
#   'that',
#   'are',
#   'almost',
#   'universall',
#   'accepted',
#   'the',
#   'geometr',
#   'for'],
#  ['instance',
#   'the',
#   'taught',
#   'ou',
#   'at',
#   'school',
#   'is',
#   'founded',
#   'on',
#   'a',
#   'misconception'],
#  [],
#  ['is',
#   'not',
#   'that',
#   'rather',
#   'a',
#   'large',
#   'thing',
#   'to',
#   'expect',
#   'us',
#   'to',
#   'begin',
#   'upon'],
#  ['said', 'filb', 'an', 'argumentative', 'person', 'with', 'red', 'hair'],
#  [],
#  ['i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'ask',
#   'ou',
#   'to',
#   'accept',
#   'an',
#   'thing',
#   'without',
#   'reasonable'],
#  ['ground',
#   'for',
#   'it',
#   'you',
#   'will',
#   'soon',
#   'admit',
#   'as',
#   'much',
#   'as',
#   'i',
#   'need',
#   'from',
#   'ou',
#   'you'],
#  ['know',
#   'of',
#   'course',
#   'that',
#   'a',
#   'mathematical',
#   'line',
#   'a',
#   'line',
#   'of',
#   'thickness',
#   'nil'],
#  ['has',
#   'no',
#   'real',
#   'existence',
#   'the',
#   'taught',
#   'ou',
#   'that',
#   'neither',
#   'has',
#   'a'],
#  ['mathematical', 'plane', 'these', 'things', 'are', 'mere', 'abstractions'],
#  [],
#  ['that', 'is', 'all', 'right', 'said', 'the', 'ps', 'chologist'],
#  [],
#  ['nor',
#   'having',
#   'onl',
#   'length',
#   'breadth',
#   'and',
#   'thickness',
#   'can',
#   'a',
#   'cube',
#   'have',
#   'a'],
#  ['real', 'existence'],
#  [],
#  ['there',
#   'i',
#   'object',
#   'said',
#   'filb',
#   'of',
#   'course',
#   'a',
#   'solid',
#   'bod',
#   'ma',
#   'exist',
#   'all'],
#  ['real', 'things'],
#  [],
#  ['so',
#   'most',
#   'people',
#   'think',
#   'but',
#   'wait',
#   'a',
#   'moment',
#   'can',
#   'an',
#   'instantaneous'],
#  ['cube', 'exist'],
#  [],
#  ['don', 't', 'follow', 'ou', 'said', 'filb'],
#  [],
#  ['can',
#   'a',
#   'cube',
#   'that',
#   'does',
#   'not',
#   'last',
#   'for',
#   'an',
#   'time',
#   'at',
#   'all',
#   'have',
#   'a',
#   'real'],
#  ['existence'],
#  [],
#  ['filb',
#   'became',
#   'pensive',
#   'clearl',
#   'the',
#   'time',
#   'traveller',
#   'proceeded',
#   'an'],
#  ['real',
#   'bod',
#   'must',
#   'have',
#   'extension',
#   'in',
#   'four',
#   'directions',
#   'it',
#   'must',
#   'have'],
#  ['length',
#   'breadth',
#   'thickness',
#   'and',
#   'duration',
#   'but',
#   'through',
#   'a',
#   'natural'],
#  ['infirmit',
#   'of',
#   'the',
#   'flesh',
#   'which',
#   'i',
#   'will',
#   'explain',
#   'to',
#   'ou',
#   'in',
#   'a',
#   'moment',
#   'we'],
#  ['incline',
#   'to',
#   'overlook',
#   'this',
#   'fact',
#   'there',
#   'are',
#   'reall',
#   'four',
#   'dimensions'],
#  ['three',
#   'which',
#   'we',
#   'call',
#   'the',
#   'three',
#   'planes',
#   'of',
#   'space',
#   'and',
#   'a',
#   'fourth',
#   'time'],
#  ['there',
#   'is',
#   'however',
#   'a',
#   'tendenc',
#   'to',
#   'draw',
#   'an',
#   'unreal',
#   'distinction',
#   'between'],
#  ['the',
#   'former',
#   'three',
#   'dimensions',
#   'and',
#   'the',
#   'latter',
#   'because',
#   'it',
#   'happens',
#   'that'],
#  ['our',
#   'consciousness',
#   'moves',
#   'intermittentl',
#   'in',
#   'one',
#   'direction',
#   'along',
#   'the'],
#  ['latter',
#   'from',
#   'the',
#   'beginning',
#   'to',
#   'the',
#   'end',
#   'of',
#   'our',
#   'lives'],
#  [],
#  ['that',
#   'said',
#   'a',
#   'ver',
#   'oung',
#   'man',
#   'making',
#   'spasmodic',
#   'efforts',
#   'to',
#   'relight'],
#  ['his', 'cigar', 'over', 'the', 'lamp', 'that', 'ver', 'clear', 'indeed'],
#  [],
#  ['now',
#   'it',
#   'is',
#   'ver',
#   'remarkable',
#   'that',
#   'this',
#   'is',
#   'so',
#   'extensivel',
#   'overlooked'],
#  ['continued',
#   'the',
#   'time',
#   'traveller',
#   'with',
#   'a',
#   'slight',
#   'accession',
#   'of'],
#  ['cheerfulness',
#   'reall',
#   'this',
#   'is',
#   'what',
#   'is',
#   'meant',
#   'b',
#   'the',
#   'fourth',
#   'dimension'],
#  ['though',
#   'some',
#   'people',
#   'who',
#   'talk',
#   'about',
#   'the',
#   'fourth',
#   'dimension',
#   'do',
#   'not',
#   'know'],
#  ['the',
#   'mean',
#   'it',
#   'it',
#   'is',
#   'onl',
#   'another',
#   'wa',
#   'of',
#   'looking',
#   'at',
#   'time',
#   'there',
#   'is'],
#  ['no',
#   'difference',
#   'between',
#   'time',
#   'and',
#   'an',
#   'of',
#   'the',
#   'three',
#   'dimensions',
#   'of',
#   'space'],
#  ['except',
#   'that',
#   'our',
#   'consciousness',
#   'moves',
#   'along',
#   'it',
#   'but',
#   'some',
#   'foolish'],
#  ['people',
#   'have',
#   'got',
#   'hold',
#   'of',
#   'the',
#   'wrong',
#   'side',
#   'of',
#   'that',
#   'idea',
#   'you',
#   'have',
#   'all'],
#  ['heard',
#   'what',
#   'the',
#   'have',
#   'to',
#   'sa',
#   'about',
#   'this',
#   'fourth',
#   'dimension'],
#  [],
#  ['i', 'have', 'not', 'said', 'the', 'provincial', 'ma', 'or'],
#  [],
#  ['it',
#   'is',
#   'simpl',
#   'this',
#   'that',
#   'space',
#   'as',
#   'our',
#   'mathematicians',
#   'have',
#   'it',
#   'is'],
#  ['spoken',
#   'of',
#   'as',
#   'having',
#   'three',
#   'dimensions',
#   'which',
#   'one',
#   'ma',
#   'call',
#   'length'],
#  ['breadth',
#   'and',
#   'thickness',
#   'and',
#   'is',
#   'alwa',
#   's',
#   'definable',
#   'b',
#   'reference',
#   'to'],
#  ['three',
#   'planes',
#   'each',
#   'at',
#   'right',
#   'angles',
#   'to',
#   'the',
#   'others',
#   'but',
#   'some'],
#  ['philosophical',
#   'people',
#   'have',
#   'been',
#   'asking',
#   'wh',
#   'three',
#   'dimensions'],
#  ['particularl',
#   'wh',
#   'not',
#   'another',
#   'direction',
#   'at',
#   'right',
#   'angles',
#   'to',
#   'the',
#   'other'],
#  ['three',
#   'and',
#   'have',
#   'even',
#   'tried',
#   'to',
#   'construct',
#   'a',
#   'four',
#   'dimension',
#   'geometr'],
#  ['professor',
#   'simon',
#   'newcomb',
#   'was',
#   'expounding',
#   'this',
#   'to',
#   'the',
#   'new',
#   'york'],
#  ['mathematical',
#   'societ',
#   'onl',
#   'a',
#   'month',
#   'or',
#   'so',
#   'ago',
#   'you',
#   'know',
#   'how',
#   'on',
#   'a',
#   'flat'],
#  ['surface',
#   'which',
#   'has',
#   'onl',
#   'two',
#   'dimensions',
#   'we',
#   'can',
#   'represent',
#   'a',
#   'figure',
#   'of'],
#  ['a',
#   'three',
#   'dimensional',
#   'solid',
#   'and',
#   'similarl',
#   'the',
#   'think',
#   'that',
#   'b',
#   'models'],
#  ['of',
#   'three',
#   'dimensions',
#   'the',
#   'could',
#   'represent',
#   'one',
#   'of',
#   'four',
#   'if',
#   'the',
#   'could'],
#  ['master', 'the', 'perspective', 'of', 'the', 'thing', 'see'],
#  [],
#  ['i',
#   'think',
#   'so',
#   'murmured',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'and',
#   'knitting',
#   'his'],
#  ['brows',
#   'he',
#   'lapsed',
#   'into',
#   'an',
#   'introspective',
#   'state',
#   'his',
#   'lips',
#   'moving',
#   'as',
#   'one'],
#  ['who',
#   'repeats',
#   'm',
#   'stic',
#   'words',
#   'yes',
#   'i',
#   'think',
#   'i',
#   'see',
#   'it',
#   'now',
#   'he',
#   'said',
#   'after'],
#  ['some', 'time', 'brightening', 'in', 'a', 'quite', 'transitor', 'manner'],
#  [],
#  ['well',
#   'i',
#   'do',
#   'not',
#   'mind',
#   'telling',
#   'ou',
#   'i',
#   'have',
#   'been',
#   'at',
#   'work',
#   'upon',
#   'this'],
#  ['geometr',
#   'of',
#   'four',
#   'dimensions',
#   'for',
#   'some',
#   'time',
#   'some',
#   'of',
#   'm',
#   'results'],
#  ['are',
#   'curious',
#   'for',
#   'instance',
#   'here',
#   'is',
#   'a',
#   'portrait',
#   'of',
#   'a',
#   'man',
#   'at',
#   'eight'],
#  ['ears',
#   'old',
#   'another',
#   'at',
#   'fifteen',
#   'another',
#   'at',
#   'seventeen',
#   'another',
#   'at'],
#  ['twent',
#   'three',
#   'and',
#   'so',
#   'on',
#   'all',
#   'these',
#   'are',
#   'evidentl',
#   'sections',
#   'as',
#   'it'],
#  ['were',
#   'three',
#   'dimensional',
#   'representations',
#   'of',
#   'his',
#   'four',
#   'dimensioned'],
#  ['being', 'which', 'is', 'a', 'fixed', 'and', 'unalterable', 'thing'],
#  [],
#  ['scientific',
#   'people',
#   'proceeded',
#   'the',
#   'time',
#   'traveller',
#   'after',
#   'the',
#   'pause'],
#  ['required',
#   'for',
#   'the',
#   'proper',
#   'assimilation',
#   'of',
#   'this',
#   'know',
#   'ver',
#   'well',
#   'that'],
#  ['time',
#   'is',
#   'onl',
#   'a',
#   'kind',
#   'of',
#   'space',
#   'here',
#   'is',
#   'a',
#   'popular',
#   'scientific',
#   'diagram'],
#  ['a',
#   'weather',
#   'record',
#   'this',
#   'line',
#   'i',
#   'trace',
#   'with',
#   'm',
#   'finger',
#   'shows',
#   'the'],
#  ['movement',
#   'of',
#   'the',
#   'barometer',
#   'yesterda',
#   'it',
#   'was',
#   'so',
#   'high',
#   'esterda',
#   'night'],
#  ['it',
#   'fell',
#   'then',
#   'this',
#   'morning',
#   'it',
#   'rose',
#   'again',
#   'and',
#   'so',
#   'gentl',
#   'upward',
#   'to'],
#  ['here',
#   'surel',
#   'the',
#   'mercur',
#   'did',
#   'not',
#   'trace',
#   'this',
#   'line',
#   'in',
#   'an',
#   'of',
#   'the'],
#  ['dimensions',
#   'of',
#   'space',
#   'generall',
#   'recogni',
#   'ed',
#   'but',
#   'certainl',
#   'it',
#   'traced'],
#  ['such',
#   'a',
#   'line',
#   'and',
#   'that',
#   'line',
#   'therefore',
#   'we',
#   'must',
#   'conclude',
#   'was',
#   'along'],
#  ['the', 'time', 'dimension'],
#  [],
#  ['but',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'staring',
#   'hard',
#   'at',
#   'a',
#   'coal',
#   'in',
#   'the',
#   'fire',
#   'if'],
#  ['time',
#   'is',
#   'reall',
#   'onl',
#   'a',
#   'fourth',
#   'dimension',
#   'of',
#   'space',
#   'wh',
#   'is',
#   'it',
#   'and',
#   'wh'],
#  ['has',
#   'it',
#   'alwa',
#   's',
#   'been',
#   'regarded',
#   'as',
#   'something',
#   'different',
#   'and',
#   'wh',
#   'cannot'],
#  ['we',
#   'move',
#   'in',
#   'time',
#   'as',
#   'we',
#   'move',
#   'about',
#   'in',
#   'the',
#   'other',
#   'dimensions',
#   'of',
#   'space'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'smiled',
#   'are',
#   'ou',
#   'sure',
#   'we',
#   'can',
#   'move',
#   'freel',
#   'in'],
#  ['space',
#   'right',
#   'and',
#   'left',
#   'we',
#   'can',
#   'go',
#   'backward',
#   'and',
#   'forward',
#   'freel',
#   'enough'],
#  ['and',
#   'men',
#   'alwa',
#   's',
#   'have',
#   'done',
#   'so',
#   'i',
#   'admit',
#   'we',
#   'move',
#   'freel',
#   'in',
#   'two'],
#  ['dimensions',
#   'but',
#   'how',
#   'about',
#   'up',
#   'and',
#   'down',
#   'gravitation',
#   'limits',
#   'us',
#   'there'],
#  [],
#  ['not',
#   'exactl',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'there',
#   'are',
#   'balloons'],
#  [],
#  ['but',
#   'before',
#   'the',
#   'balloons',
#   'save',
#   'for',
#   'spasmodic',
#   'jumping',
#   'and',
#   'the'],
#  ['inequalities',
#   'of',
#   'the',
#   'surface',
#   'man',
#   'had',
#   'no',
#   'freedom',
#   'of',
#   'vertical'],
#  ['movement'],
#  [],
#  ['still',
#   'the',
#   'could',
#   'move',
#   'a',
#   'little',
#   'up',
#   'and',
#   'down',
#   'said',
#   'the',
#   'medical',
#   'man'],
#  [],
#  ['easier', 'far', 'easier', 'down', 'than', 'up'],
#  [],
#  ['and',
#   'ou',
#   'cannot',
#   'move',
#   'at',
#   'all',
#   'in',
#   'time',
#   'ou',
#   'cannot',
#   'get',
#   'awa',
#   'from',
#   'the'],
#  ['present', 'moment'],
#  [],
#  ['m',
#   'dear',
#   'sir',
#   'that',
#   'is',
#   'just',
#   'where',
#   'ou',
#   'are',
#   'wrong',
#   'that',
#   'is',
#   'just',
#   'where'],
#  ['the',
#   'whole',
#   'world',
#   'has',
#   'gone',
#   'wrong',
#   'we',
#   'are',
#   'alwa',
#   's',
#   'getting',
#   'awa',
#   'from',
#   'the'],
#  ['present',
#   'moment',
#   'our',
#   'mental',
#   'existences',
#   'which',
#   'are',
#   'immaterial',
#   'and',
#   'have'],
#  ['no',
#   'dimensions',
#   'are',
#   'passing',
#   'along',
#   'the',
#   'time',
#   'dimension',
#   'with',
#   'a',
#   'uniform'],
#  ['velocit',
#   'from',
#   'the',
#   'cradle',
#   'to',
#   'the',
#   'grave',
#   'just',
#   'as',
#   'we',
#   'should',
#   'travel',
#   'down'],
#  ['if',
#   'we',
#   'began',
#   'our',
#   'existence',
#   'fift',
#   'miles',
#   'above',
#   'the',
#   'earth',
#   's',
#   'surface'],
#  [],
#  ['but',
#   'the',
#   'great',
#   'difficult',
#   'is',
#   'this',
#   'interrupted',
#   'the',
#   'ps',
#   'chologist'],
#  ['you',
#   'can',
#   'move',
#   'about',
#   'in',
#   'all',
#   'directions',
#   'of',
#   'space',
#   'but',
#   'ou',
#   'cannot'],
#  ['move', 'about', 'in', 'time'],
#  [],
#  ['that',
#   'is',
#   'the',
#   'germ',
#   'of',
#   'm',
#   'great',
#   'discover',
#   'but',
#   'ou',
#   'are',
#   'wrong',
#   'to',
#   'sa'],
#  ['that',
#   'we',
#   'cannot',
#   'move',
#   'about',
#   'in',
#   'time',
#   'for',
#   'instance',
#   'if',
#   'i',
#   'am',
#   'recalling'],
#  ['an',
#   'incident',
#   'ver',
#   'vividl',
#   'i',
#   'go',
#   'back',
#   'to',
#   'the',
#   'instant',
#   'of',
#   'its',
#   'occurrence'],
#  ['i',
#   'become',
#   'absent',
#   'minded',
#   'as',
#   'ou',
#   'sa',
#   'i',
#   'jump',
#   'back',
#   'for',
#   'a',
#   'moment',
#   'of'],
#  ['course',
#   'we',
#   'have',
#   'no',
#   'means',
#   'of',
#   'sta',
#   'ing',
#   'back',
#   'for',
#   'an',
#   'length',
#   'of',
#   'time',
#   'an'],
#  ['more',
#   'than',
#   'a',
#   'savage',
#   'or',
#   'an',
#   'animal',
#   'has',
#   'of',
#   'sta',
#   'ing',
#   'six',
#   'feet',
#   'above',
#   'the'],
#  ['ground',
#   'but',
#   'a',
#   'civili',
#   'ed',
#   'man',
#   'is',
#   'better',
#   'off',
#   'than',
#   'the',
#   'savage',
#   'in',
#   'this'],
#  ['respect',
#   'he',
#   'can',
#   'go',
#   'up',
#   'against',
#   'gravitation',
#   'in',
#   'a',
#   'balloon',
#   'and',
#   'wh'],
#  ['should',
#   'he',
#   'not',
#   'hope',
#   'that',
#   'ultimatel',
#   'he',
#   'ma',
#   'be',
#   'able',
#   'to',
#   'stop',
#   'or'],
#  ['accelerate',
#   'his',
#   'drift',
#   'along',
#   'the',
#   'time',
#   'dimension',
#   'or',
#   'even',
#   'turn',
#   'about'],
#  ['and', 'travel', 'the', 'other', 'wa'],
#  [],
#  ['oh', 'this', 'began', 'filb', 'is', 'all'],
#  [],
#  ['wh', 'not', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['it', 's', 'against', 'reason', 'said', 'filb'],
#  [],
#  ['what', 'reason', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['you',
#   'can',
#   'show',
#   'black',
#   'is',
#   'white',
#   'b',
#   'argument',
#   'said',
#   'filb',
#   'but',
#   'ou',
#   'will'],
#  ['never', 'convince', 'me'],
#  [],
#  ['possibl',
#   'not',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'but',
#   'now',
#   'ou',
#   'begin',
#   'to',
#   'see'],
#  ['the',
#   'object',
#   'of',
#   'm',
#   'investigations',
#   'into',
#   'the',
#   'geometr',
#   'of',
#   'four'],
#  ['dimensions',
#   'long',
#   'ago',
#   'i',
#   'had',
#   'a',
#   'vague',
#   'inkling',
#   'of',
#   'a',
#   'machine'],
#  [],
#  ['to',
#   'travel',
#   'through',
#   'time',
#   'exclaimed',
#   'the',
#   'ver',
#   'young',
#   'man'],
#  [],
#  ['that',
#   'shall',
#   'travel',
#   'indifferentl',
#   'in',
#   'an',
#   'direction',
#   'of',
#   'space',
#   'and',
#   'time'],
#  ['as', 'the', 'driver', 'determines'],
#  [],
#  ['filb', 'contented', 'himself', 'with', 'laughter'],
#  [],
#  ['but',
#   'i',
#   'have',
#   'experimental',
#   'verification',
#   'said',
#   'the',
#   'time',
#   'traveller'],
#  [],
#  ['it',
#   'would',
#   'be',
#   'remarkabl',
#   'convenient',
#   'for',
#   'the',
#   'historian',
#   'the'],
#  ['ps',
#   'chologist',
#   'suggested',
#   'one',
#   'might',
#   'travel',
#   'back',
#   'and',
#   'verif',
#   'the'],
#  ['accepted',
#   'account',
#   'of',
#   'the',
#   'battle',
#   'of',
#   'hastings',
#   'for',
#   'instance'],
#  [],
#  ['don',
#   't',
#   'ou',
#   'think',
#   'ou',
#   'would',
#   'attract',
#   'attention',
#   'said',
#   'the',
#   'medical',
#   'man'],
#  ['our',
#   'ancestors',
#   'had',
#   'no',
#   'great',
#   'tolerance',
#   'for',
#   'anachronisms'],
#  [],
#  ['one',
#   'might',
#   'get',
#   'one',
#   's',
#   'greek',
#   'from',
#   'the',
#   'ver',
#   'lips',
#   'of',
#   'homer',
#   'and',
#   'plato'],
#  ['the', 'ver', 'young', 'man', 'thought'],
#  [],
#  ['in',
#   'which',
#   'case',
#   'the',
#   'would',
#   'certainl',
#   'plough',
#   'ou',
#   'for',
#   'the',
#   'little',
#   'go'],
#  ['the', 'german', 'scholars', 'have', 'improved', 'greek', 'so', 'much'],
#  [],
#  ['then',
#   'there',
#   'is',
#   'the',
#   'future',
#   'said',
#   'the',
#   'ver',
#   'young',
#   'man',
#   'just',
#   'think'],
#  ['one',
#   'might',
#   'invest',
#   'all',
#   'one',
#   's',
#   'mone',
#   'leave',
#   'it',
#   'to',
#   'accumulate',
#   'at'],
#  ['interest', 'and', 'hurr', 'on', 'ahead'],
#  [],
#  ['to',
#   'discover',
#   'a',
#   'societ',
#   'said',
#   'i',
#   'erected',
#   'on',
#   'a',
#   'strictl',
#   'communistic'],
#  ['basis'],
#  [],
#  ['of',
#   'all',
#   'the',
#   'wild',
#   'extravagant',
#   'theories',
#   'began',
#   'the',
#   'ps',
#   'chologist'],
#  [],
#  ['yes',
#   'so',
#   'it',
#   'seemed',
#   'to',
#   'me',
#   'and',
#   'so',
#   'i',
#   'never',
#   'talked',
#   'of',
#   'it',
#   'until'],
#  [],
#  ['experimental',
#   'verification',
#   'cried',
#   'i',
#   'you',
#   'are',
#   'going',
#   'to',
#   'verif'],
#  ['that'],
#  [],
#  ['the',
#   'experiment',
#   'cried',
#   'filb',
#   'who',
#   'was',
#   'getting',
#   'brain',
#   'wear'],
#  [],
#  ['let',
#   's',
#   'see',
#   'our',
#   'experiment',
#   'an',
#   'how',
#   'said',
#   'the',
#   'ps',
#   'chologist',
#   'though'],
#  ['it', 's', 'all', 'humbug', 'ou', 'know'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'smiled',
#   'round',
#   'at',
#   'us',
#   'then',
#   'still',
#   'smiling',
#   'faintl'],
#  ['and',
#   'with',
#   'his',
#   'hands',
#   'deep',
#   'in',
#   'his',
#   'trousers',
#   'pockets',
#   'he',
#   'walked',
#   'slowl'],
#  ['out',
#   'of',
#   'the',
#   'room',
#   'and',
#   'we',
#   'heard',
#   'his',
#   'slippers',
#   'shuffling',
#   'down',
#   'the',
#   'long'],
#  ['passage', 'to', 'his', 'laborator'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'looked',
#   'at',
#   'us',
#   'i',
#   'wonder',
#   'what',
#   'he',
#   's',
#   'got'],
#  [],
#  ['some',
#   'sleight',
#   'of',
#   'hand',
#   'trick',
#   'or',
#   'other',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'and'],
#  ['filb',
#   'tried',
#   'to',
#   'tell',
#   'us',
#   'about',
#   'a',
#   'conjurer',
#   'he',
#   'had',
#   'seen',
#   'at',
#   'burslem',
#   'but'],
#  ['before',
#   'he',
#   'had',
#   'finished',
#   'his',
#   'preface',
#   'the',
#   'time',
#   'traveller',
#   'came',
#   'back',
#   'and'],
#  ['filb', 's', 'anecdote', 'collapsed'],
#  [],
#  ['the',
#   'thing',
#   'the',
#   'time',
#   'traveller',
#   'held',
#   'in',
#   'his',
#   'hand',
#   'was',
#   'a',
#   'glittering'],
#  ['metallic',
#   'framework',
#   'scarcel',
#   'larger',
#   'than',
#   'a',
#   'small',
#   'clock',
#   'and',
#   'ver'],
#  ['delicatel',
#   'made',
#   'there',
#   'was',
#   'ivor',
#   'in',
#   'it',
#   'and',
#   'some',
#   'transparent'],
#  ['cr',
#   'stalline',
#   'substance',
#   'and',
#   'now',
#   'i',
#   'must',
#   'be',
#   'explicit',
#   'for',
#   'this',
#   'that'],
#  ['follows',
#   'unless',
#   'his',
#   'explanation',
#   'is',
#   'to',
#   'be',
#   'accepted',
#   'is',
#   'an',
#   'absolutel'],
#  ['unaccountable',
#   'thing',
#   'he',
#   'took',
#   'one',
#   'of',
#   'the',
#   'small',
#   'octagonal',
#   'tables',
#   'that'],
#  ['were',
#   'scattered',
#   'about',
#   'the',
#   'room',
#   'and',
#   'set',
#   'it',
#   'in',
#   'front',
#   'of',
#   'the',
#   'fire',
#   'with'],
#  ['two',
#   'legs',
#   'on',
#   'the',
#   'hearthrug',
#   'on',
#   'this',
#   'table',
#   'he',
#   'placed',
#   'the',
#   'mechanism'],
#  ['then',
#   'he',
#   'drew',
#   'up',
#   'a',
#   'chair',
#   'and',
#   'sat',
#   'down',
#   'the',
#   'onl',
#   'other',
#   'object',
#   'on',
#   'the'],
#  ['table',
#   'was',
#   'a',
#   'small',
#   'shaded',
#   'lamp',
#   'the',
#   'bright',
#   'light',
#   'of',
#   'which',
#   'fell',
#   'upon'],
#  ['the',
#   'model',
#   'there',
#   'were',
#   'also',
#   'perhaps',
#   'a',
#   'do',
#   'en',
#   'candles',
#   'about',
#   'two',
#   'in'],
#  ['brass',
#   'candlesticks',
#   'upon',
#   'the',
#   'mantel',
#   'and',
#   'several',
#   'in',
#   'sconces',
#   'so',
#   'that'],
#  ['the',
#   'room',
#   'was',
#   'brilliantl',
#   'illuminated',
#   'i',
#   'sat',
#   'in',
#   'a',
#   'low',
#   'arm',
#   'chair'],
#  ['nearest',
#   'the',
#   'fire',
#   'and',
#   'i',
#   'drew',
#   'this',
#   'forward',
#   'so',
#   'as',
#   'to',
#   'be',
#   'almost',
#   'between'],
#  ['the',
#   'time',
#   'traveller',
#   'and',
#   'the',
#   'fireplace',
#   'filb',
#   'sat',
#   'behind',
#   'him',
#   'looking'],
#  ['over',
#   'his',
#   'shoulder',
#   'the',
#   'medical',
#   'man',
#   'and',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'watched'],
#  ['him',
#   'in',
#   'profile',
#   'from',
#   'the',
#   'right',
#   'the',
#   'ps',
#   'chologist',
#   'from',
#   'the',
#   'left',
#   'the'],
#  ['ver',
#   'young',
#   'man',
#   'stood',
#   'behind',
#   'the',
#   'ps',
#   'chologist',
#   'we',
#   'were',
#   'all',
#   'on',
#   'the'],
#  ['alert',
#   'it',
#   'appears',
#   'incredible',
#   'to',
#   'me',
#   'that',
#   'an',
#   'kind',
#   'of',
#   'trick',
#   'however'],
#  ['subtl',
#   'conceived',
#   'and',
#   'however',
#   'adroitl',
#   'done',
#   'could',
#   'have',
#   'been',
#   'pla',
#   'ed'],
#  ['upon', 'us', 'under', 'these', 'conditions'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'looked',
#   'at',
#   'us',
#   'and',
#   'then',
#   'at',
#   'the',
#   'mechanism',
#   'well'],
#  ['said', 'the', 'ps', 'chologist'],
#  [],
#  ['this',
#   'little',
#   'affair',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'resting',
#   'his',
#   'elbows'],
#  ['upon',
#   'the',
#   'table',
#   'and',
#   'pressing',
#   'his',
#   'hands',
#   'together',
#   'above',
#   'the',
#   'apparatus'],
#  ['is',
#   'onl',
#   'a',
#   'model',
#   'it',
#   'is',
#   'm',
#   'plan',
#   'for',
#   'a',
#   'machine',
#   'to',
#   'travel',
#   'through'],
#  ['time',
#   'you',
#   'will',
#   'notice',
#   'that',
#   'it',
#   'looks',
#   'singularl',
#   'askew',
#   'and',
#   'that',
#   'there'],
#  ['is',
#   'an',
#   'odd',
#   'twinkling',
#   'appearance',
#   'about',
#   'this',
#   'bar',
#   'as',
#   'though',
#   'it',
#   'was',
#   'in'],
#  ['some',
#   'wa',
#   'unreal',
#   'he',
#   'pointed',
#   'to',
#   'the',
#   'part',
#   'with',
#   'his',
#   'finger',
#   'also'],
#  ['here',
#   'is',
#   'one',
#   'little',
#   'white',
#   'lever',
#   'and',
#   'here',
#   'is',
#   'another'],
#  [],
#  ['the',
#   'medical',
#   'man',
#   'got',
#   'up',
#   'out',
#   'of',
#   'his',
#   'chair',
#   'and',
#   'peered',
#   'into',
#   'the',
#   'thing'],
#  ['it', 's', 'beautifull', 'made', 'he', 'said'],
#  [],
#  ['it',
#   'took',
#   'two',
#   'ears',
#   'to',
#   'make',
#   'retorted',
#   'the',
#   'time',
#   'traveller',
#   'then',
#   'when'],
#  ['we',
#   'had',
#   'all',
#   'imitated',
#   'the',
#   'action',
#   'of',
#   'the',
#   'medical',
#   'man',
#   'he',
#   'said',
#   'now',
#   'i'],
#  ['want',
#   'ou',
#   'clearl',
#   'to',
#   'understand',
#   'that',
#   'this',
#   'lever',
#   'being',
#   'pressed',
#   'over'],
#  ['sends',
#   'the',
#   'machine',
#   'gliding',
#   'into',
#   'the',
#   'future',
#   'and',
#   'this',
#   'other',
#   'reverses'],
#  ['the',
#   'motion',
#   'this',
#   'saddle',
#   'represents',
#   'the',
#   'seat',
#   'of',
#   'a',
#   'time',
#   'traveller'],
#  ['presentl',
#   'i',
#   'am',
#   'going',
#   'to',
#   'press',
#   'the',
#   'lever',
#   'and',
#   'off',
#   'the',
#   'machine',
#   'will'],
#  ['go',
#   'it',
#   'will',
#   'vanish',
#   'pass',
#   'into',
#   'future',
#   'time',
#   'and',
#   'disappear',
#   'have',
#   'a'],
#  ['good',
#   'look',
#   'at',
#   'the',
#   'thing',
#   'look',
#   'at',
#   'the',
#   'table',
#   'too',
#   'and',
#   'satisf'],
#  ['ourselves',
#   'there',
#   'is',
#   'no',
#   'tricker',
#   'i',
#   'don',
#   't',
#   'want',
#   'to',
#   'waste',
#   'this',
#   'model'],
#  ['and', 'then', 'be', 'told', 'i', 'm', 'a', 'quack'],
#  [],
#  ['there',
#   'was',
#   'a',
#   'minute',
#   's',
#   'pause',
#   'perhaps',
#   'the',
#   'ps',
#   'chologist',
#   'seemed',
#   'about',
#   'to'],
#  ['speak',
#   'to',
#   'me',
#   'but',
#   'changed',
#   'his',
#   'mind',
#   'then',
#   'the',
#   'time',
#   'traveller',
#   'put',
#   'forth'],
#  ['his',
#   'finger',
#   'towards',
#   'the',
#   'lever',
#   'no',
#   'he',
#   'said',
#   'suddenl',
#   'lend',
#   'me',
#   'our'],
#  ['hand',
#   'and',
#   'turning',
#   'to',
#   'the',
#   'ps',
#   'chologist',
#   'he',
#   'took',
#   'that',
#   'individual',
#   's'],
#  ['hand',
#   'in',
#   'his',
#   'own',
#   'and',
#   'told',
#   'him',
#   'to',
#   'put',
#   'out',
#   'his',
#   'forefinger',
#   'so',
#   'that',
#   'it'],
#  ['was',
#   'the',
#   'ps',
#   'chologist',
#   'himself',
#   'who',
#   'sent',
#   'forth',
#   'the',
#   'model',
#   'time',
#   'machine'],
#  ['on',
#   'its',
#   'interminable',
#   'vo',
#   'age',
#   'we',
#   'all',
#   'saw',
#   'the',
#   'lever',
#   'turn',
#   'i',
#   'am'],
#  ['absolutel',
#   'certain',
#   'there',
#   'was',
#   'no',
#   'tricker',
#   'there',
#   'was',
#   'a',
#   'breath',
#   'of'],
#  ['wind',
#   'and',
#   'the',
#   'lamp',
#   'flame',
#   'jumped',
#   'one',
#   'of',
#   'the',
#   'candles',
#   'on',
#   'the',
#   'mantel'],
#  ['was',
#   'blown',
#   'out',
#   'and',
#   'the',
#   'little',
#   'machine',
#   'suddenl',
#   'swung',
#   'round',
#   'became'],
#  ['indistinct',
#   'was',
#   'seen',
#   'as',
#   'a',
#   'ghost',
#   'for',
#   'a',
#   'second',
#   'perhaps',
#   'as',
#   'an',
#   'edd',
#   'of'],
#  ['faintl',
#   'glittering',
#   'brass',
#   'and',
#   'ivor',
#   'and',
#   'it',
#   'was',
#   'gone',
#   'vanished',
#   'save'],
#  ['for', 'the', 'lamp', 'the', 'table', 'was', 'bare'],
#  [],
#  ['ever',
#   'one',
#   'was',
#   'silent',
#   'for',
#   'a',
#   'minute',
#   'then',
#   'filb',
#   'said',
#   'he',
#   'was',
#   'damned'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'recovered',
#   'from',
#   'his',
#   'stupor',
#   'and',
#   'suddenl',
#   'looked'],
#  ['under',
#   'the',
#   'table',
#   'at',
#   'that',
#   'the',
#   'time',
#   'traveller',
#   'laughed',
#   'cheerfull'],
#  ['well',
#   'he',
#   'said',
#   'with',
#   'a',
#   'reminiscence',
#   'of',
#   'the',
#   'ps',
#   'chologist',
#   'then'],
#  ['getting',
#   'up',
#   'he',
#   'went',
#   'to',
#   'the',
#   'tobacco',
#   'jar',
#   'on',
#   'the',
#   'mantel',
#   'and',
#   'with',
#   'his'],
#  ['back', 'to', 'us', 'began', 'to', 'fill', 'his', 'pipe'],
#  [],
#  ['we',
#   'stared',
#   'at',
#   'each',
#   'other',
#   'look',
#   'here',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'are',
#   'ou'],
#  ['in',
#   'earnest',
#   'about',
#   'this',
#   'do',
#   'ou',
#   'seriousl',
#   'believe',
#   'that',
#   'that',
#   'machine'],
#  ['has', 'travelled', 'into', 'time'],
#  [],
#  ['certainl',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'stooping',
#   'to',
#   'light',
#   'a',
#   'spill',
#   'at'],
#  ['the',
#   'fire',
#   'then',
#   'he',
#   'turned',
#   'lighting',
#   'his',
#   'pipe',
#   'to',
#   'look',
#   'at',
#   'the'],
#  ['ps',
#   'chologist',
#   's',
#   'face',
#   'the',
#   'ps',
#   'chologist',
#   'to',
#   'show',
#   'that',
#   'he',
#   'was',
#   'not'],
#  ['unhinged',
#   'helped',
#   'himself',
#   'to',
#   'a',
#   'cigar',
#   'and',
#   'tried',
#   'to',
#   'light',
#   'it',
#   'uncut'],
#  ['what',
#   'is',
#   'more',
#   'i',
#   'have',
#   'a',
#   'big',
#   'machine',
#   'nearl',
#   'finished',
#   'in',
#   'there',
#   'he'],
#  ['indicated',
#   'the',
#   'laborator',
#   'and',
#   'when',
#   'that',
#   'is',
#   'put',
#   'together',
#   'i',
#   'mean',
#   'to'],
#  ['have', 'a', 'journe', 'on', 'm', 'own', 'account'],
#  [],
#  ['you',
#   'mean',
#   'to',
#   'sa',
#   'that',
#   'that',
#   'machine',
#   'has',
#   'travelled',
#   'into',
#   'the',
#   'future'],
#  ['said', 'filb'],
#  [],
#  ['into',
#   'the',
#   'future',
#   'or',
#   'the',
#   'past',
#   'i',
#   'don',
#   't',
#   'for',
#   'certain',
#   'know',
#   'which'],
#  [],
#  ['after',
#   'an',
#   'interval',
#   'the',
#   'ps',
#   'chologist',
#   'had',
#   'an',
#   'inspiration',
#   'it',
#   'must',
#   'have'],
#  ['gone',
#   'into',
#   'the',
#   'past',
#   'if',
#   'it',
#   'has',
#   'gone',
#   'an',
#   'where',
#   'he',
#   'said'],
#  [],
#  ['wh', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['because',
#   'i',
#   'presume',
#   'that',
#   'it',
#   'has',
#   'not',
#   'moved',
#   'in',
#   'space',
#   'and',
#   'if',
#   'it'],
#  ['travelled',
#   'into',
#   'the',
#   'future',
#   'it',
#   'would',
#   'still',
#   'be',
#   'here',
#   'all',
#   'this',
#   'time'],
#  ['since', 'it', 'must', 'have', 'travelled', 'through', 'this', 'time'],
#  [],
#  ['but',
#   'i',
#   'said',
#   'if',
#   'it',
#   'travelled',
#   'into',
#   'the',
#   'past',
#   'it',
#   'would',
#   'have',
#   'been'],
#  ['visible',
#   'when',
#   'we',
#   'came',
#   'first',
#   'into',
#   'this',
#   'room',
#   'and',
#   'last',
#   'thursda',
#   'when',
#   'we'],
#  ['were',
#   'here',
#   'and',
#   'the',
#   'thursda',
#   'before',
#   'that',
#   'and',
#   'so',
#   'forth'],
#  [],
#  ['serious',
#   'objections',
#   'remarked',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'with',
#   'an',
#   'air',
#   'of'],
#  ['impartialit', 'turning', 'towards', 'the', 'time', 'traveller'],
#  [],
#  ['not',
#   'a',
#   'bit',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'and',
#   'to',
#   'the',
#   'ps',
#   'chologist',
#   'you'],
#  ['think',
#   'you',
#   'can',
#   'explain',
#   'that',
#   'it',
#   's',
#   'presentation',
#   'below',
#   'the',
#   'threshold'],
#  ['ou', 'know', 'diluted', 'presentation'],
#  [],
#  ['of',
#   'course',
#   'said',
#   'the',
#   'ps',
#   'chologist',
#   'and',
#   'reassured',
#   'us',
#   'that',
#   's',
#   'a'],
#  ['simple',
#   'point',
#   'of',
#   'ps',
#   'cholog',
#   'i',
#   'should',
#   'have',
#   'thought',
#   'of',
#   'it',
#   'it',
#   's',
#   'plain'],
#  ['enough',
#   'and',
#   'helps',
#   'the',
#   'paradox',
#   'delightfull',
#   'we',
#   'cannot',
#   'see',
#   'it',
#   'nor'],
#  ['can',
#   'we',
#   'appreciate',
#   'this',
#   'machine',
#   'an',
#   'more',
#   'than',
#   'we',
#   'can',
#   'the',
#   'spoke',
#   'of'],
#  ['a',
#   'wheel',
#   'spinning',
#   'or',
#   'a',
#   'bullet',
#   'fl',
#   'ing',
#   'through',
#   'the',
#   'air',
#   'if',
#   'it',
#   'is'],
#  ['travelling',
#   'through',
#   'time',
#   'fift',
#   'times',
#   'or',
#   'a',
#   'hundred',
#   'times',
#   'faster',
#   'than'],
#  ['we',
#   'are',
#   'if',
#   'it',
#   'gets',
#   'through',
#   'a',
#   'minute',
#   'while',
#   'we',
#   'get',
#   'through',
#   'a',
#   'second'],
#  ['the',
#   'impression',
#   'it',
#   'creates',
#   'will',
#   'of',
#   'course',
#   'be',
#   'onl',
#   'one',
#   'fiftieth',
#   'or'],
#  ['one',
#   'hundredth',
#   'of',
#   'what',
#   'it',
#   'would',
#   'make',
#   'if',
#   'it',
#   'were',
#   'not',
#   'travelling',
#   'in'],
#  ['time',
#   'that',
#   's',
#   'plain',
#   'enough',
#   'he',
#   'passed',
#   'his',
#   'hand',
#   'through',
#   'the',
#   'space',
#   'in'],
#  ['which',
#   'the',
#   'machine',
#   'had',
#   'been',
#   'you',
#   'see',
#   'he',
#   'said',
#   'laughing'],
#  [],
#  ['we',
#   'sat',
#   'and',
#   'stared',
#   'at',
#   'the',
#   'vacant',
#   'table',
#   'for',
#   'a',
#   'minute',
#   'or',
#   'so',
#   'then',
#   'the'],
#  ['time',
#   'traveller',
#   'asked',
#   'us',
#   'what',
#   'we',
#   'thought',
#   'of',
#   'it',
#   'all'],
#  [],
#  ['it',
#   'sounds',
#   'plausible',
#   'enough',
#   'to',
#   'night',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'but'],
#  ['wait',
#   'until',
#   'to',
#   'morrow',
#   'wait',
#   'for',
#   'the',
#   'common',
#   'sense',
#   'of',
#   'the',
#   'morning'],
#  [],
#  ['would',
#   'ou',
#   'like',
#   'to',
#   'see',
#   'the',
#   'time',
#   'machine',
#   'itself',
#   'asked',
#   'the',
#   'time'],
#  ['traveller',
#   'and',
#   'therewith',
#   'taking',
#   'the',
#   'lamp',
#   'in',
#   'his',
#   'hand',
#   'he',
#   'led',
#   'the'],
#  ['wa',
#   'down',
#   'the',
#   'long',
#   'draught',
#   'corridor',
#   'to',
#   'his',
#   'laborator',
#   'i',
#   'remember'],
#  ['vividl',
#   'the',
#   'flickering',
#   'light',
#   'his',
#   'queer',
#   'broad',
#   'head',
#   'in',
#   'silhouette'],
#  ['the',
#   'dance',
#   'of',
#   'the',
#   'shadows',
#   'how',
#   'we',
#   'all',
#   'followed',
#   'him',
#   'pu',
#   'led',
#   'but'],
#  ['incredulous',
#   'and',
#   'how',
#   'there',
#   'in',
#   'the',
#   'laborator',
#   'we',
#   'beheld',
#   'a',
#   'larger'],
#  ['edition',
#   'of',
#   'the',
#   'little',
#   'mechanism',
#   'which',
#   'we',
#   'had',
#   'seen',
#   'vanish',
#   'from',
#   'before'],
#  ['our',
#   'e',
#   'es',
#   'parts',
#   'were',
#   'of',
#   'nickel',
#   'parts',
#   'of',
#   'ivor',
#   'parts',
#   'had',
#   'certainl'],
#  ['been',
#   'filed',
#   'or',
#   'sawn',
#   'out',
#   'of',
#   'rock',
#   'cr',
#   'stal',
#   'the',
#   'thing',
#   'was',
#   'generall'],
#  ['complete',
#   'but',
#   'the',
#   'twisted',
#   'cr',
#   'stalline',
#   'bars',
#   'la',
#   'unfinished',
#   'upon',
#   'the'],
#  ['bench',
#   'beside',
#   'some',
#   'sheets',
#   'of',
#   'drawings',
#   'and',
#   'i',
#   'took',
#   'one',
#   'up',
#   'for',
#   'a',
#   'better'],
#  ['look', 'at', 'it', 'quart', 'it', 'seemed', 'to', 'be'],
#  [],
#  ['look',
#   'here',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'are',
#   'ou',
#   'perfectl',
#   'serious'],
#  ['or',
#   'is',
#   'this',
#   'a',
#   'trick',
#   'like',
#   'that',
#   'ghost',
#   'ou',
#   'showed',
#   'us',
#   'last',
#   'christmas'],
#  [],
#  ['upon',
#   'that',
#   'machine',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'holding',
#   'the',
#   'lamp'],
#  ['aloft',
#   'i',
#   'intend',
#   'to',
#   'explore',
#   'time',
#   'is',
#   'that',
#   'plain',
#   'i',
#   'was',
#   'never',
#   'more'],
#  ['serious', 'in', 'm', 'life'],
#  [],
#  ['none', 'of', 'us', 'quite', 'knew', 'how', 'to', 'take', 'it'],
#  [],
#  ['i',
#   'caught',
#   'filb',
#   's',
#   'e',
#   'e',
#   'over',
#   'the',
#   'shoulder',
#   'of',
#   'the',
#   'medical',
#   'man',
#   'and',
#   'he'],
#  ['winked', 'at', 'me', 'solemnl'],
#  [],
#  [],
#  [],
#  [],
#  ['ii'],
#  [],
#  [],
#  ['i',
#   'think',
#   'that',
#   'at',
#   'that',
#   'time',
#   'none',
#   'of',
#   'us',
#   'quite',
#   'believed',
#   'in',
#   'the',
#   'time'],
#  ['machine',
#   'the',
#   'fact',
#   'is',
#   'the',
#   'time',
#   'traveller',
#   'was',
#   'one',
#   'of',
#   'those',
#   'men',
#   'who'],
#  ['are',
#   'too',
#   'clever',
#   'to',
#   'be',
#   'believed',
#   'ou',
#   'never',
#   'felt',
#   'that',
#   'ou',
#   'saw',
#   'all',
#   'round'],
#  ['him',
#   'ou',
#   'alwa',
#   's',
#   'suspected',
#   'some',
#   'subtle',
#   'reserve',
#   'some',
#   'ingenuit',
#   'in'],
#  ['ambush',
#   'behind',
#   'his',
#   'lucid',
#   'frankness',
#   'had',
#   'filb',
#   'shown',
#   'the',
#   'model',
#   'and'],
#  ['explained',
#   'the',
#   'matter',
#   'in',
#   'the',
#   'time',
#   'traveller',
#   's',
#   'words',
#   'we',
#   'should',
#   'have'],
#  ['shown',
#   'him',
#   'far',
#   'less',
#   'scepticism',
#   'for',
#   'we',
#   'should',
#   'have',
#   'perceived',
#   'his'],
#  ['motives',
#   'a',
#   'pork',
#   'butcher',
#   'could',
#   'understand',
#   'filb',
#   'but',
#   'the',
#   'time'],
#  ['traveller',
#   'had',
#   'more',
#   'than',
#   'a',
#   'touch',
#   'of',
#   'whim',
#   'among',
#   'his',
#   'elements',
#   'and',
#   'we'],
#  ['distrusted',
#   'him',
#   'things',
#   'that',
#   'would',
#   'have',
#   'made',
#   'the',
#   'frame',
#   'of',
#   'a',
#   'less'],
#  ['clever',
#   'man',
#   'seemed',
#   'tricks',
#   'in',
#   'his',
#   'hands',
#   'it',
#   'is',
#   'a',
#   'mistake',
#   'to',
#   'do',
#   'things'],
#  ['too',
#   'easil',
#   'the',
#   'serious',
#   'people',
#   'who',
#   'took',
#   'him',
#   'seriousl',
#   'never',
#   'felt'],
#  ['quite',
#   'sure',
#   'of',
#   'his',
#   'deportment',
#   'the',
#   'were',
#   'somehow',
#   'aware',
#   'that',
#   'trusting'],
#  ['their',
#   'reputations',
#   'for',
#   'judgment',
#   'with',
#   'him',
#   'was',
#   'like',
#   'furnishing',
#   'a'],
#  ['nurser',
#   'with',
#   'egg',
#   'shell',
#   'china',
#   'so',
#   'i',
#   'don',
#   't',
#   'think',
#   'an',
#   'of',
#   'us',
#   'said',
#   'ver'],
#  ['much',
#   'about',
#   'time',
#   'travelling',
#   'in',
#   'the',
#   'interval',
#   'between',
#   'that',
#   'thursda',
#   'and'],
#  ['the',
#   'next',
#   'though',
#   'its',
#   'odd',
#   'potentialities',
#   'ran',
#   'no',
#   'doubt',
#   'in',
#   'most',
#   'of'],
#  ['our',
#   'minds',
#   'its',
#   'plausibilit',
#   'that',
#   'is',
#   'its',
#   'practical',
#   'incredibleness'],
#  ['the',
#   'curious',
#   'possibilities',
#   'of',
#   'anachronism',
#   'and',
#   'of',
#   'utter',
#   'confusion',
#   'it'],
#  ['suggested',
#   'for',
#   'm',
#   'own',
#   'part',
#   'i',
#   'was',
#   'particularl',
#   'preoccupied',
#   'with',
#   'the'],
#  ['trick',
#   'of',
#   'the',
#   'model',
#   'that',
#   'i',
#   'remember',
#   'discussing',
#   'with',
#   'the',
#   'medical',
#   'man'],
#  ['whom',
#   'i',
#   'met',
#   'on',
#   'frida',
#   'at',
#   'the',
#   'linnaean',
#   'he',
#   'said',
#   'he',
#   'had',
#   'seen',
#   'a',
#   'similar'],
#  ['thing',
#   'at',
#   'tubingen',
#   'and',
#   'laid',
#   'considerable',
#   'stress',
#   'on',
#   'the',
#   'blowing',
#   'out'],
#  ['of',
#   'the',
#   'candle',
#   'but',
#   'how',
#   'the',
#   'trick',
#   'was',
#   'done',
#   'he',
#   'could',
#   'not',
#   'explain'],
#  [],
#  ['the',
#   'next',
#   'thursda',
#   'i',
#   'went',
#   'again',
#   'to',
#   'richmond',
#   'i',
#   'suppose',
#   'i',
#   'was',
#   'one',
#   'of'],
#  ['the',
#   'time',
#   'traveller',
#   's',
#   'most',
#   'constant',
#   'guests',
#   'and',
#   'arriving',
#   'late',
#   'found'],
#  ['four',
#   'or',
#   'five',
#   'men',
#   'alread',
#   'assembled',
#   'in',
#   'his',
#   'drawing',
#   'room',
#   'the',
#   'medical'],
#  ['man',
#   'was',
#   'standing',
#   'before',
#   'the',
#   'fire',
#   'with',
#   'a',
#   'sheet',
#   'of',
#   'paper',
#   'in',
#   'one',
#   'hand'],
#  ['and',
#   'his',
#   'watch',
#   'in',
#   'the',
#   'other',
#   'i',
#   'looked',
#   'round',
#   'for',
#   'the',
#   'time',
#   'traveller'],
#  ['and',
#   'it',
#   's',
#   'half',
#   'past',
#   'seven',
#   'now',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'i',
#   'suppose'],
#  ['we', 'd', 'better', 'have', 'dinner'],
#  [],
#  ['where', 's', 'said', 'i', 'naming', 'our', 'host'],
#  [],
#  ['you',
#   've',
#   'just',
#   'come',
#   'it',
#   's',
#   'rather',
#   'odd',
#   'he',
#   's',
#   'unavoidabl',
#   'detained',
#   'he'],
#  ['asks',
#   'me',
#   'in',
#   'this',
#   'note',
#   'to',
#   'lead',
#   'off',
#   'with',
#   'dinner',
#   'at',
#   'seven',
#   'if',
#   'he',
#   's',
#   'not'],
#  ['back', 'sa', 's', 'he', 'll', 'explain', 'when', 'he', 'comes'],
#  [],
#  ['it',
#   'seems',
#   'a',
#   'pit',
#   'to',
#   'let',
#   'the',
#   'dinner',
#   'spoil',
#   'said',
#   'the',
#   'editor',
#   'of',
#   'a'],
#  ['well',
#   'known',
#   'dail',
#   'paper',
#   'and',
#   'thereupon',
#   'the',
#   'doctor',
#   'rang',
#   'the',
#   'bell'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'was',
#   'the',
#   'onl',
#   'person',
#   'besides',
#   'the',
#   'doctor',
#   'and',
#   'm',
#   'self'],
#  ['who',
#   'had',
#   'attended',
#   'the',
#   'previous',
#   'dinner',
#   'the',
#   'other',
#   'men',
#   'were',
#   'blank',
#   'the'],
#  ['editor',
#   'aforementioned',
#   'a',
#   'certain',
#   'journalist',
#   'and',
#   'another',
#   'a',
#   'quiet'],
#  ['sh',
#   'man',
#   'with',
#   'a',
#   'beard',
#   'whom',
#   'i',
#   'didn',
#   't',
#   'know',
#   'and',
#   'who',
#   'as',
#   'far',
#   'as',
#   'm'],
#  ['observation',
#   'went',
#   'never',
#   'opened',
#   'his',
#   'mouth',
#   'all',
#   'the',
#   'evening',
#   'there',
#   'was'],
#  ['some',
#   'speculation',
#   'at',
#   'the',
#   'dinner',
#   'table',
#   'about',
#   'the',
#   'time',
#   'traveller',
#   's'],
#  ['absence',
#   'and',
#   'i',
#   'suggested',
#   'time',
#   'travelling',
#   'in',
#   'a',
#   'half',
#   'jocular',
#   'spirit'],
#  ['the',
#   'editor',
#   'wanted',
#   'that',
#   'explained',
#   'to',
#   'him',
#   'and',
#   'the',
#   'ps',
#   'chologist'],
#  ['volunteered',
#   'a',
#   'wooden',
#   'account',
#   'of',
#   'the',
#   'ingenious',
#   'paradox',
#   'and',
#   'trick',
#   'we'],
#  ['had',
#   'witnessed',
#   'that',
#   'da',
#   'week',
#   'he',
#   'was',
#   'in',
#   'the',
#   'midst',
#   'of',
#   'his',
#   'exposition'],
#  ['when',
#   'the',
#   'door',
#   'from',
#   'the',
#   'corridor',
#   'opened',
#   'slowl',
#   'and',
#   'without',
#   'noise',
#   'i'],
#  ['was',
#   'facing',
#   'the',
#   'door',
#   'and',
#   'saw',
#   'it',
#   'first',
#   'hallo',
#   'i',
#   'said',
#   'at',
#   'last'],
#  ['and',
#   'the',
#   'door',
#   'opened',
#   'wider',
#   'and',
#   'the',
#   'time',
#   'traveller',
#   'stood',
#   'before',
#   'us'],
#  ['i',
#   'gave',
#   'a',
#   'cr',
#   'of',
#   'surprise',
#   'good',
#   'heavens',
#   'man',
#   'what',
#   's',
#   'the',
#   'matter'],
#  ['cried',
#   'the',
#   'medical',
#   'man',
#   'who',
#   'saw',
#   'him',
#   'next',
#   'and',
#   'the',
#   'whole',
#   'tableful'],
#  ['turned', 'towards', 'the', 'door'],
#  [],
#  ['he',
#   'was',
#   'in',
#   'an',
#   'ama',
#   'ing',
#   'plight',
#   'his',
#   'coat',
#   'was',
#   'dust',
#   'and',
#   'dirt',
#   'and'],
#  ['smeared',
#   'with',
#   'green',
#   'down',
#   'the',
#   'sleeves',
#   'his',
#   'hair',
#   'disordered',
#   'and',
#   'as',
#   'it'],
#  ['seemed',
#   'to',
#   'me',
#   'gre',
#   'er',
#   'either',
#   'with',
#   'dust',
#   'and',
#   'dirt',
#   'or',
#   'because',
#   'its',
#   'colour'],
#  ['had',
#   'actuall',
#   'faded',
#   'his',
#   'face',
#   'was',
#   'ghastl',
#   'pale',
#   'his',
#   'chin',
#   'had',
#   'a',
#   'brown'],
#  ['cut',
#   'on',
#   'it',
#   'a',
#   'cut',
#   'half',
#   'healed',
#   'his',
#   'expression',
#   'was',
#   'haggard',
#   'and',
#   'drawn'],
#  ['as',
#   'b',
#   'intense',
#   'suffering',
#   'for',
#   'a',
#   'moment',
#   'he',
#   'hesitated',
#   'in',
#   'the',
#   'doorwa'],
#  ['as',
#   'if',
#   'he',
#   'had',
#   'been',
#   'da',
#   'led',
#   'b',
#   'the',
#   'light',
#   'then',
#   'he',
#   'came',
#   'into',
#   'the',
#   'room'],
#  ['he',
#   'walked',
#   'with',
#   'just',
#   'such',
#   'a',
#   'limp',
#   'as',
#   'i',
#   'have',
#   'seen',
#   'in',
#   'footsore',
#   'tramps'],
#  ['we',
#   'stared',
#   'at',
#   'him',
#   'in',
#   'silence',
#   'expecting',
#   'him',
#   'to',
#   'speak'],
#  [],
#  ['he',
#   'said',
#   'not',
#   'a',
#   'word',
#   'but',
#   'came',
#   'painfull',
#   'to',
#   'the',
#   'table',
#   'and',
#   'made',
#   'a'],
#  ['motion',
#   'towards',
#   'the',
#   'wine',
#   'the',
#   'editor',
#   'filled',
#   'a',
#   'glass',
#   'of',
#   'champagne',
#   'and'],
#  ['pushed',
#   'it',
#   'towards',
#   'him',
#   'he',
#   'drained',
#   'it',
#   'and',
#   'it',
#   'seemed',
#   'to',
#   'do',
#   'him',
#   'good'],
#  ['for',
#   'he',
#   'looked',
#   'round',
#   'the',
#   'table',
#   'and',
#   'the',
#   'ghost',
#   'of',
#   'his',
#   'old',
#   'smile'],
#  ['flickered',
#   'across',
#   'his',
#   'face',
#   'what',
#   'on',
#   'earth',
#   'have',
#   'ou',
#   'been',
#   'up',
#   'to',
#   'man'],
#  ['said',
#   'the',
#   'doctor',
#   'the',
#   'time',
#   'traveller',
#   'did',
#   'not',
#   'seem',
#   'to',
#   'hear',
#   'don',
#   't',
#   'let'],
#  ['me',
#   'disturb',
#   'ou',
#   'he',
#   'said',
#   'with',
#   'a',
#   'certain',
#   'faltering',
#   'articulation'],
#  ['i',
#   'm',
#   'all',
#   'right',
#   'he',
#   'stopped',
#   'held',
#   'out',
#   'his',
#   'glass',
#   'for',
#   'more',
#   'and',
#   'took'],
#  ['it',
#   'off',
#   'at',
#   'a',
#   'draught',
#   'that',
#   's',
#   'good',
#   'he',
#   'said',
#   'his',
#   'e',
#   'es',
#   'grew',
#   'brighter'],
#  ['and',
#   'a',
#   'faint',
#   'colour',
#   'came',
#   'into',
#   'his',
#   'cheeks',
#   'his',
#   'glance',
#   'flickered',
#   'over'],
#  ['our',
#   'faces',
#   'with',
#   'a',
#   'certain',
#   'dull',
#   'approval',
#   'and',
#   'then',
#   'went',
#   'round',
#   'the',
#   'warm'],
#  ['and',
#   'comfortable',
#   'room',
#   'then',
#   'he',
#   'spoke',
#   'again',
#   'still',
#   'as',
#   'it',
#   'were',
#   'feeling'],
#  ['his',
#   'wa',
#   'among',
#   'his',
#   'words',
#   'i',
#   'm',
#   'going',
#   'to',
#   'wash',
#   'and',
#   'dress',
#   'and',
#   'then',
#   'i',
#   'll'],
#  ['come',
#   'down',
#   'and',
#   'explain',
#   'things',
#   'save',
#   'me',
#   'some',
#   'of',
#   'that',
#   'mutton',
#   'i',
#   'm'],
#  ['starving', 'for', 'a', 'bit', 'of', 'meat'],
#  [],
#  ['he',
#   'looked',
#   'across',
#   'at',
#   'the',
#   'editor',
#   'who',
#   'was',
#   'a',
#   'rare',
#   'visitor',
#   'and',
#   'hoped',
#   'he'],
#  ['was',
#   'all',
#   'right',
#   'the',
#   'editor',
#   'began',
#   'a',
#   'question',
#   'tell',
#   'ou',
#   'presentl'],
#  ['said',
#   'the',
#   'time',
#   'traveller',
#   'i',
#   'm',
#   'funn',
#   'be',
#   'all',
#   'right',
#   'in',
#   'a',
#   'minute'],
#  [],
#  ['he',
#   'put',
#   'down',
#   'his',
#   'glass',
#   'and',
#   'walked',
#   'towards',
#   'the',
#   'staircase',
#   'door',
#   'again'],
#  ['i',
#   'remarked',
#   'his',
#   'lameness',
#   'and',
#   'the',
#   'soft',
#   'padding',
#   'sound',
#   'of',
#   'his',
#   'footfall'],
#  ['and',
#   'standing',
#   'up',
#   'in',
#   'm',
#   'place',
#   'i',
#   'saw',
#   'his',
#   'feet',
#   'as',
#   'he',
#   'went',
#   'out',
#   'he',
#   'had'],
#  ['nothing',
#   'on',
#   'them',
#   'but',
#   'a',
#   'pair',
#   'of',
#   'tattered',
#   'blood',
#   'stained',
#   'socks',
#   'then',
#   'the'],
#  ['door',
#   'closed',
#   'upon',
#   'him',
#   'i',
#   'had',
#   'half',
#   'a',
#   'mind',
#   'to',
#   'follow',
#   'till',
#   'i',
#   'remembered'],
#  ['how',
#   'he',
#   'detested',
#   'an',
#   'fuss',
#   'about',
#   'himself',
#   'for',
#   'a',
#   'minute',
#   'perhaps',
#   'm'],
#  ['mind',
#   'was',
#   'wool',
#   'gathering',
#   'then',
#   'remarkable',
#   'behaviour',
#   'of',
#   'an',
#   'eminent'],
#  ['scientist',
#   'i',
#   'heard',
#   'the',
#   'editor',
#   'sa',
#   'thinking',
#   'after',
#   'his',
#   'wont',
#   'in'],
#  ['headlines',
#   'and',
#   'this',
#   'brought',
#   'm',
#   'attention',
#   'back',
#   'to',
#   'the',
#   'bright'],
#  ['dinner', 'table'],
#  [],
#  ['what',
#   's',
#   'the',
#   'game',
#   'said',
#   'the',
#   'journalist',
#   'has',
#   'he',
#   'been',
#   'doing',
#   'the'],
#  ['amateur',
#   'cadger',
#   'i',
#   'don',
#   't',
#   'follow',
#   'i',
#   'met',
#   'the',
#   'e',
#   'e',
#   'of',
#   'the',
#   'ps',
#   'chologist'],
#  ['and',
#   'read',
#   'm',
#   'own',
#   'interpretation',
#   'in',
#   'his',
#   'face',
#   'i',
#   'thought',
#   'of',
#   'the',
#   'time'],
#  ['traveller',
#   'limping',
#   'painfull',
#   'upstairs',
#   'i',
#   'don',
#   't',
#   'think',
#   'an',
#   'one',
#   'else',
#   'had'],
#  ['noticed', 'his', 'lameness'],
#  [],
#  ['the',
#   'first',
#   'to',
#   'recover',
#   'completel',
#   'from',
#   'this',
#   'surprise',
#   'was',
#   'the',
#   'medical'],
#  ['man',
#   'who',
#   'rang',
#   'the',
#   'bell',
#   'the',
#   'time',
#   'traveller',
#   'hated',
#   'to',
#   'have',
#   'servants'],
#  ['waiting',
#   'at',
#   'dinner',
#   'for',
#   'a',
#   'hot',
#   'plate',
#   'at',
#   'that',
#   'the',
#   'editor',
#   'turned',
#   'to',
#   'his'],
#  ['knife',
#   'and',
#   'fork',
#   'with',
#   'a',
#   'grunt',
#   'and',
#   'the',
#   'silent',
#   'man',
#   'followed',
#   'suit',
#   'the'],
#  ['dinner',
#   'was',
#   'resumed',
#   'conversation',
#   'was',
#   'exclamator',
#   'for',
#   'a',
#   'little',
#   'while'],
#  ['with',
#   'gaps',
#   'of',
#   'wonderment',
#   'and',
#   'then',
#   'the',
#   'editor',
#   'got',
#   'fervent',
#   'in',
#   'his'],
#  ['curiosit',
#   'does',
#   'our',
#   'friend',
#   'eke',
#   'out',
#   'his',
#   'modest',
#   'income',
#   'with',
#   'a'],
#  ['crossing',
#   'or',
#   'has',
#   'he',
#   'his',
#   'nebuchadne',
#   'ar',
#   'phases',
#   'he',
#   'inquired',
#   'i',
#   'feel'],
#  ['assured',
#   'it',
#   's',
#   'this',
#   'business',
#   'of',
#   'the',
#   'time',
#   'machine',
#   'i',
#   'said',
#   'and',
#   'took',
#   'up'],
#  ['the',
#   'ps',
#   'chologist',
#   's',
#   'account',
#   'of',
#   'our',
#   'previous',
#   'meeting',
#   'the',
#   'new',
#   'guests'],
#  ['were',
#   'frankl',
#   'incredulous',
#   'the',
#   'editor',
#   'raised',
#   'objections',
#   'what',
#   'was'],
#  ['this',
#   'time',
#   'travelling',
#   'a',
#   'man',
#   'couldn',
#   't',
#   'cover',
#   'himself',
#   'with',
#   'dust',
#   'b'],
#  ['rolling',
#   'in',
#   'a',
#   'paradox',
#   'could',
#   'he',
#   'and',
#   'then',
#   'as',
#   'the',
#   'idea',
#   'came',
#   'home',
#   'to'],
#  ['him',
#   'he',
#   'resorted',
#   'to',
#   'caricature',
#   'hadn',
#   't',
#   'the',
#   'an',
#   'clothes',
#   'brushes',
#   'in'],
#  ['the',
#   'future',
#   'the',
#   'journalist',
#   'too',
#   'would',
#   'not',
#   'believe',
#   'at',
#   'an',
#   'price',
#   'and'],
#  ['joined',
#   'the',
#   'editor',
#   'in',
#   'the',
#   'eas',
#   'work',
#   'of',
#   'heaping',
#   'ridicule',
#   'on',
#   'the',
#   'whole'],
#  ['thing',
#   'the',
#   'were',
#   'both',
#   'the',
#   'new',
#   'kind',
#   'of',
#   'journalist',
#   'ver',
#   'jo',
#   'ous'],
#  ['irreverent',
#   'oung',
#   'men',
#   'our',
#   'special',
#   'correspondent',
#   'in',
#   'the',
#   'da'],
#  ['after',
#   'to',
#   'morrow',
#   'reports',
#   'the',
#   'journalist',
#   'was',
#   'sa',
#   'ing',
#   'or',
#   'rather'],
#  ['shouting',
#   'when',
#   'the',
#   'time',
#   'traveller',
#   'came',
#   'back',
#   'he',
#   'was',
#   'dressed',
#   'in'],
#  ['ordinar',
#   'evening',
#   'clothes',
#   'and',
#   'nothing',
#   'save',
#   'his',
#   'haggard',
#   'look',
#   'remained'],
#  ['of', 'the', 'change', 'that', 'had', 'startled', 'me'],
#  [],
#  ['i',
#   'sa',
#   'said',
#   'the',
#   'editor',
#   'hilariousl',
#   'these',
#   'chaps',
#   'here',
#   'sa',
#   'ou',
#   'have'],
#  ['been',
#   'travelling',
#   'into',
#   'the',
#   'middle',
#   'of',
#   'next',
#   'week',
#   'tell',
#   'us',
#   'all',
#   'about'],
#  ['little',
#   'roseber',
#   'will',
#   'ou',
#   'what',
#   'will',
#   'ou',
#   'take',
#   'for',
#   'the',
#   'lot'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'came',
#   'to',
#   'the',
#   'place',
#   'reserved',
#   'for',
#   'him',
#   'without',
#   'a'],
#  ['word',
#   'he',
#   'smiled',
#   'quietl',
#   'in',
#   'his',
#   'old',
#   'wa',
#   'where',
#   's',
#   'm',
#   'mutton',
#   'he'],
#  ['said',
#   'what',
#   'a',
#   'treat',
#   'it',
#   'is',
#   'to',
#   'stick',
#   'a',
#   'fork',
#   'into',
#   'meat',
#   'again'],
#  [],
#  ['stor', 'cried', 'the', 'editor'],
#  [],
#  ['stor',
#   'be',
#   'damned',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'i',
#   'want',
#   'something',
#   'to'],
#  ['eat',
#   'i',
#   'won',
#   't',
#   'sa',
#   'a',
#   'word',
#   'until',
#   'i',
#   'get',
#   'some',
#   'peptone',
#   'into',
#   'm',
#   'arteries'],
#  ['thanks', 'and', 'the', 'salt'],
#  [],
#  ['one', 'word', 'said', 'i', 'have', 'ou', 'been', 'time', 'travelling'],
#  [],
#  ['yes',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'with',
#   'his',
#   'mouth',
#   'full',
#   'nodding',
#   'his'],
#  ['head'],
#  [],
#  ['i',
#   'd',
#   'give',
#   'a',
#   'shilling',
#   'a',
#   'line',
#   'for',
#   'a',
#   'verbatim',
#   'note',
#   'said',
#   'the',
#   'editor'],
#  ['the',
#   'time',
#   'traveller',
#   'pushed',
#   'his',
#   'glass',
#   'towards',
#   'the',
#   'silent',
#   'man',
#   'and',
#   'rang'],
#  ['it',
#   'with',
#   'his',
# ...
#   'you',
#   'who'],
#  ['have',
#   'never',
#   'seen',
#   'the',
#   'like',
#   'can',
#   'scarcel',
#   'imagine',
#   'what',
#   'delicate',
#   'and'],
#  ['wonderful',
#   'flowers',
#   'countless',
#   'ears',
#   'of',
#   'culture',
#   'had',
#   'created',
#   'then'],
#  ['someone',
#   'suggested',
#   'that',
#   'their',
#   'pla',
#   'thing',
#   'should',
#   'be',
#   'exhibited',
#   'in',
#   'the'],
#  ['nearest',
#   'building',
#   'and',
#   'so',
#   'i',
#   'was',
#   'led',
#   'past',
#   'the',
#   'sphinx',
#   'of',
#   'white',
#   'marble'],
#  ['which',
#   'had',
#   'seemed',
#   'to',
#   'watch',
#   'me',
#   'all',
#   'the',
#   'while',
#   'with',
#   'a',
#   'smile',
#   'at',
#   'm'],
#  ['astonishment',
#   'towards',
#   'a',
#   'vast',
#   'gre',
#   'edifice',
#   'of',
#   'fretted',
#   'stone',
#   'as',
#   'i'],
#  ['went',
#   'with',
#   'them',
#   'the',
#   'memor',
#   'of',
#   'm',
#   'confident',
#   'anticipations',
#   'of',
#   'a'],
#  ['profoundl',
#   'grave',
#   'and',
#   'intellectual',
#   'posterit',
#   'came',
#   'with',
#   'irresistible'],
#  ['merriment', 'to', 'm', 'mind'],
#  [],
#  ['the',
#   'building',
#   'had',
#   'a',
#   'huge',
#   'entr',
#   'and',
#   'was',
#   'altogether',
#   'of',
#   'colossal'],
#  ['dimensions',
#   'i',
#   'was',
#   'naturall',
#   'most',
#   'occupied',
#   'with',
#   'the',
#   'growing',
#   'crowd',
#   'of'],
#  ['little',
#   'people',
#   'and',
#   'with',
#   'the',
#   'big',
#   'open',
#   'portals',
#   'that',
#   'awned',
#   'before',
#   'me'],
#  ['shadow',
#   'and',
#   'm',
#   'sterious',
#   'm',
#   'general',
#   'impression',
#   'of',
#   'the',
#   'world',
#   'i',
#   'saw'],
#  ['over',
#   'their',
#   'heads',
#   'was',
#   'a',
#   'tangled',
#   'waste',
#   'of',
#   'beautiful',
#   'bushes',
#   'and'],
#  ['flowers',
#   'a',
#   'long',
#   'neglected',
#   'and',
#   'et',
#   'weedless',
#   'garden',
#   'i',
#   'saw',
#   'a',
#   'number'],
#  ['of',
#   'tall',
#   'spikes',
#   'of',
#   'strange',
#   'white',
#   'flowers',
#   'measuring',
#   'a',
#   'foot',
#   'perhaps'],
#  ['across',
#   'the',
#   'spread',
#   'of',
#   'the',
#   'waxen',
#   'petals',
#   'the',
#   'grew',
#   'scattered',
#   'as',
#   'if'],
#  ['wild',
#   'among',
#   'the',
#   'variegated',
#   'shrubs',
#   'but',
#   'as',
#   'i',
#   'sa',
#   'i',
#   'did',
#   'not',
#   'examine'],
#  ['them',
#   'closel',
#   'at',
#   'this',
#   'time',
#   'the',
#   'time',
#   'machine',
#   'was',
#   'left',
#   'deserted',
#   'on',
#   'the'],
#  ['turf', 'among', 'the', 'rhododendrons'],
#  [],
#  ['the',
#   'arch',
#   'of',
#   'the',
#   'doorwa',
#   'was',
#   'richl',
#   'carved',
#   'but',
#   'naturall',
#   'i',
#   'did'],
#  ['not',
#   'observe',
#   'the',
#   'carving',
#   'ver',
#   'narrowl',
#   'though',
#   'i',
#   'fancied',
#   'i',
#   'saw'],
#  ['suggestions',
#   'of',
#   'old',
#   'phoenician',
#   'decorations',
#   'as',
#   'i',
#   'passed',
#   'through',
#   'and'],
#  ['it',
#   'struck',
#   'me',
#   'that',
#   'the',
#   'were',
#   'ver',
#   'badl',
#   'broken',
#   'and',
#   'weather',
#   'worn'],
#  ['several',
#   'more',
#   'brightl',
#   'clad',
#   'people',
#   'met',
#   'me',
#   'in',
#   'the',
#   'doorwa',
#   'and',
#   'so',
#   'we'],
#  ['entered',
#   'i',
#   'dressed',
#   'in',
#   'ding',
#   'nineteenth',
#   'centur',
#   'garments',
#   'looking'],
#  ['grotesque',
#   'enough',
#   'garlanded',
#   'with',
#   'flowers',
#   'and',
#   'surrounded',
#   'b',
#   'an'],
#  ['edd',
#   'ing',
#   'mass',
#   'of',
#   'bright',
#   'soft',
#   'colored',
#   'robes',
#   'and',
#   'shining',
#   'white',
#   'limbs'],
#  ['in',
#   'a',
#   'melodious',
#   'whirl',
#   'of',
#   'laughter',
#   'and',
#   'laughing',
#   'speech'],
#  [],
#  ['the',
#   'big',
#   'doorwa',
#   'opened',
#   'into',
#   'a',
#   'proportionatel',
#   'great',
#   'hall',
#   'hung',
#   'with'],
#  ['brown',
#   'the',
#   'roof',
#   'was',
#   'in',
#   'shadow',
#   'and',
#   'the',
#   'windows',
#   'partiall',
#   'gla',
#   'ed'],
#  ['with',
#   'coloured',
#   'glass',
#   'and',
#   'partiall',
#   'ungla',
#   'ed',
#   'admitted',
#   'a',
#   'tempered'],
#  ['light',
#   'the',
#   'floor',
#   'was',
#   'made',
#   'up',
#   'of',
#   'huge',
#   'blocks',
#   'of',
#   'some',
#   'ver',
#   'hard',
#   'white'],
#  ['metal',
#   'not',
#   'plates',
#   'nor',
#   'slabs',
#   'blocks',
#   'and',
#   'it',
#   'was',
#   'so',
#   'much',
#   'worn',
#   'as',
#   'i'],
#  ['judged',
#   'b',
#   'the',
#   'going',
#   'to',
#   'and',
#   'fro',
#   'of',
#   'past',
#   'generations',
#   'as',
#   'to',
#   'be',
#   'deepl'],
#  ['channelled',
#   'along',
#   'the',
#   'more',
#   'frequented',
#   'wa',
#   's',
#   'transverse',
#   'to',
#   'the',
#   'length'],
#  ['were',
#   'innumerable',
#   'tables',
#   'made',
#   'of',
#   'slabs',
#   'of',
#   'polished',
#   'stone',
#   'raised'],
#  ['perhaps',
#   'a',
#   'foot',
#   'from',
#   'the',
#   'floor',
#   'and',
#   'upon',
#   'these',
#   'were',
#   'heaps',
#   'of',
#   'fruits'],
#  ['some',
#   'i',
#   'recogni',
#   'ed',
#   'as',
#   'a',
#   'kind',
#   'of',
#   'h',
#   'pertrophied',
#   'raspberr',
#   'and',
#   'orange'],
#  ['but', 'for', 'the', 'most', 'part', 'the', 'were', 'strange'],
#  [],
#  ['between',
#   'the',
#   'tables',
#   'was',
#   'scattered',
#   'a',
#   'great',
#   'number',
#   'of',
#   'cushions'],
#  ['upon',
#   'these',
#   'm',
#   'conductors',
#   'seated',
#   'themselves',
#   'signing',
#   'for',
#   'me',
#   'to',
#   'do'],
#  ['likewise',
#   'with',
#   'a',
#   'prett',
#   'absence',
#   'of',
#   'ceremon',
#   'the',
#   'began',
#   'to',
#   'eat',
#   'the'],
#  ['fruit',
#   'with',
#   'their',
#   'hands',
#   'flinging',
#   'peel',
#   'and',
#   'stalks',
#   'and',
#   'so',
#   'forth',
#   'into'],
#  ['the',
#   'round',
#   'openings',
#   'in',
#   'the',
#   'sides',
#   'of',
#   'the',
#   'tables',
#   'i',
#   'was',
#   'not',
#   'loath',
#   'to'],
#  ['follow',
#   'their',
#   'example',
#   'for',
#   'i',
#   'felt',
#   'thirst',
#   'and',
#   'hungr',
#   'as',
#   'i',
#   'did',
#   'so',
#   'i'],
#  ['surve', 'ed', 'the', 'hall', 'at', 'm', 'leisure'],
#  [],
#  ['and',
#   'perhaps',
#   'the',
#   'thing',
#   'that',
#   'struck',
#   'me',
#   'most',
#   'was',
#   'its',
#   'dilapidated',
#   'look'],
#  ['the',
#   'stained',
#   'glass',
#   'windows',
#   'which',
#   'displa',
#   'ed',
#   'onl',
#   'a',
#   'geometrical'],
#  ['pattern',
#   'were',
#   'broken',
#   'in',
#   'man',
#   'places',
#   'and',
#   'the',
#   'curtains',
#   'that',
#   'hung'],
#  ['across',
#   'the',
#   'lower',
#   'end',
#   'were',
#   'thick',
#   'with',
#   'dust',
#   'and',
#   'it',
#   'caught',
#   'm',
#   'e',
#   'e',
#   'that'],
#  ['the',
#   'corner',
#   'of',
#   'the',
#   'marble',
#   'table',
#   'near',
#   'me',
#   'was',
#   'fractured',
#   'nevertheless'],
#  ['the',
#   'general',
#   'effect',
#   'was',
#   'extremel',
#   'rich',
#   'and',
#   'picturesque',
#   'there',
#   'were'],
#  ['perhaps',
#   'a',
#   'couple',
#   'of',
#   'hundred',
#   'people',
#   'dining',
#   'in',
#   'the',
#   'hall',
#   'and',
#   'most',
#   'of'],
#  ['them',
#   'seated',
#   'as',
#   'near',
#   'to',
#   'me',
#   'as',
#   'the',
#   'could',
#   'come',
#   'were',
#   'watching',
#   'me',
#   'with'],
#  ['interest',
#   'their',
#   'little',
#   'e',
#   'es',
#   'shining',
#   'over',
#   'the',
#   'fruit',
#   'the',
#   'were',
#   'eating'],
#  ['all',
#   'were',
#   'clad',
#   'in',
#   'the',
#   'same',
#   'soft',
#   'and',
#   'et',
#   'strong',
#   'silk',
#   'material'],
#  [],
#  ['fruit',
#   'b',
#   'the',
#   'b',
#   'was',
#   'all',
#   'their',
#   'diet',
#   'these',
#   'people',
#   'of',
#   'the',
#   'remote'],
#  ['future',
#   'were',
#   'strict',
#   'vegetarians',
#   'and',
#   'while',
#   'i',
#   'was',
#   'with',
#   'them',
#   'in',
#   'spite'],
#  ['of',
#   'some',
#   'carnal',
#   'cravings',
#   'i',
#   'had',
#   'to',
#   'be',
#   'frugivorous',
#   'also',
#   'indeed',
#   'i'],
#  ['found',
#   'afterwards',
#   'that',
#   'horses',
#   'cattle',
#   'sheep',
#   'dogs',
#   'had',
#   'followed',
#   'the'],
#  ['ichth',
#   'osaurus',
#   'into',
#   'extinction',
#   'but',
#   'the',
#   'fruits',
#   'were',
#   'ver',
#   'delightful'],
#  ['one',
#   'in',
#   'particular',
#   'that',
#   'seemed',
#   'to',
#   'be',
#   'in',
#   'season',
#   'all',
#   'the',
#   'time',
#   'i',
#   'was'],
#  ['there',
#   'a',
#   'flour',
#   'thing',
#   'in',
#   'a',
#   'three',
#   'sided',
#   'husk',
#   'was',
#   'especiall',
#   'good'],
#  ['and',
#   'i',
#   'made',
#   'it',
#   'm',
#   'staple',
#   'at',
#   'first',
#   'i',
#   'was',
#   'pu',
#   'led',
#   'b',
#   'all',
#   'these',
#   'strange'],
#  ['fruits',
#   'and',
#   'b',
#   'the',
#   'strange',
#   'flowers',
#   'i',
#   'saw',
#   'but',
#   'later',
#   'i',
#   'began',
#   'to'],
#  ['perceive', 'their', 'import'],
#  [],
#  ['however',
#   'i',
#   'am',
#   'telling',
#   'ou',
#   'of',
#   'm',
#   'fruit',
#   'dinner',
#   'in',
#   'the',
#   'distant',
#   'future'],
#  ['now',
#   'so',
#   'soon',
#   'as',
#   'm',
#   'appetite',
#   'was',
#   'a',
#   'little',
#   'checked',
#   'i',
#   'determined',
#   'to'],
#  ['make',
#   'a',
#   'resolute',
#   'attempt',
#   'to',
#   'learn',
#   'the',
#   'speech',
#   'of',
#   'these',
#   'new',
#   'men',
#   'of'],
#  ['mine',
#   'clearl',
#   'that',
#   'was',
#   'the',
#   'next',
#   'thing',
#   'to',
#   'do',
#   'the',
#   'fruits',
#   'seemed',
#   'a'],
#  ['convenient',
#   'thing',
#   'to',
#   'begin',
#   'upon',
#   'and',
#   'holding',
#   'one',
#   'of',
#   'these',
#   'up',
#   'i',
#   'began'],
#  ['a',
#   'series',
#   'of',
#   'interrogative',
#   'sounds',
#   'and',
#   'gestures',
#   'i',
#   'had',
#   'some'],
#  ['considerable',
#   'difficult',
#   'in',
#   'conve',
#   'ing',
#   'm',
#   'meaning',
#   'at',
#   'first',
#   'm',
#   'efforts'],
#  ['met',
#   'with',
#   'a',
#   'stare',
#   'of',
#   'surprise',
#   'or',
#   'inextinguishable',
#   'laughter',
#   'but'],
#  ['presentl',
#   'a',
#   'fair',
#   'haired',
#   'little',
#   'creature',
#   'seemed',
#   'to',
#   'grasp',
#   'm',
#   'intention'],
#  ['and',
#   'repeated',
#   'a',
#   'name',
#   'the',
#   'had',
#   'to',
#   'chatter',
#   'and',
#   'explain',
#   'the',
#   'business'],
#  ['at',
#   'great',
#   'length',
#   'to',
#   'each',
#   'other',
#   'and',
#   'm',
#   'first',
#   'attempts',
#   'to',
#   'make',
#   'the'],
#  ['exquisite',
#   'little',
#   'sounds',
#   'of',
#   'their',
#   'language',
#   'caused',
#   'an',
#   'immense',
#   'amount'],
#  ['of',
#   'amusement',
#   'however',
#   'i',
#   'felt',
#   'like',
#   'a',
#   'schoolmaster',
#   'amidst',
#   'children'],
#  ['and',
#   'persisted',
#   'and',
#   'presentl',
#   'i',
#   'had',
#   'a',
#   'score',
#   'of',
#   'noun',
#   'substantives',
#   'at'],
#  ['least',
#   'at',
#   'm',
#   'command',
#   'and',
#   'then',
#   'i',
#   'got',
#   'to',
#   'demonstrative',
#   'pronouns',
#   'and'],
#  ['even',
#   'the',
#   'verb',
#   'to',
#   'eat',
#   'but',
#   'it',
#   'was',
#   'slow',
#   'work',
#   'and',
#   'the',
#   'little',
#   'people'],
#  ['soon',
#   'tired',
#   'and',
#   'wanted',
#   'to',
#   'get',
#   'awa',
#   'from',
#   'm',
#   'interrogations',
#   'so',
#   'i'],
#  ['determined',
#   'rather',
#   'of',
#   'necessit',
#   'to',
#   'let',
#   'them',
#   'give',
#   'their',
#   'lessons',
#   'in'],
#  ['little',
#   'doses',
#   'when',
#   'the',
#   'felt',
#   'inclined',
#   'and',
#   'ver',
#   'little',
#   'doses',
#   'i',
#   'found'],
#  ['the',
#   'were',
#   'before',
#   'long',
#   'for',
#   'i',
#   'never',
#   'met',
#   'people',
#   'more',
#   'indolent',
#   'or',
#   'more'],
#  ['easil', 'fatigued'],
#  [],
#  ['a',
#   'queer',
#   'thing',
#   'i',
#   'soon',
#   'discovered',
#   'about',
#   'm',
#   'little',
#   'hosts',
#   'and',
#   'that',
#   'was'],
#  ['their',
#   'lack',
#   'of',
#   'interest',
#   'the',
#   'would',
#   'come',
#   'to',
#   'me',
#   'with',
#   'eager',
#   'cries',
#   'of'],
#  ['astonishment',
#   'like',
#   'children',
#   'but',
#   'like',
#   'children',
#   'the',
#   'would',
#   'soon',
#   'stop'],
#  ['examining',
#   'me',
#   'and',
#   'wander',
#   'awa',
#   'after',
#   'some',
#   'other',
#   'to',
#   'the',
#   'dinner',
#   'and',
#   'm'],
#  ['conversational',
#   'beginnings',
#   'ended',
#   'i',
#   'noted',
#   'for',
#   'the',
#   'first',
#   'time',
#   'that'],
#  ['almost',
#   'all',
#   'those',
#   'who',
#   'had',
#   'surrounded',
#   'me',
#   'at',
#   'first',
#   'were',
#   'gone',
#   'it',
#   'is'],
#  ['odd',
#   'too',
#   'how',
#   'speedil',
#   'i',
#   'came',
#   'to',
#   'disregard',
#   'these',
#   'little',
#   'people',
#   'i'],
#  ['went',
#   'out',
#   'through',
#   'the',
#   'portal',
#   'into',
#   'the',
#   'sunlit',
#   'world',
#   'again',
#   'as',
#   'soon',
#   'as'],
#  ['m',
#   'hunger',
#   'was',
#   'satisfied',
#   'i',
#   'was',
#   'continuall',
#   'meeting',
#   'more',
#   'of',
#   'these',
#   'men'],
#  ['of',
#   'the',
#   'future',
#   'who',
#   'would',
#   'follow',
#   'me',
#   'a',
#   'little',
#   'distance',
#   'chatter',
#   'and'],
#  ['laugh',
#   'about',
#   'me',
#   'and',
#   'having',
#   'smiled',
#   'and',
#   'gesticulated',
#   'in',
#   'a',
#   'friendl'],
#  ['wa', 'leave', 'me', 'again', 'to', 'm', 'own', 'devices'],
#  [],
#  ['the',
#   'calm',
#   'of',
#   'evening',
#   'was',
#   'upon',
#   'the',
#   'world',
#   'as',
#   'i',
#   'emerged',
#   'from',
#   'the',
#   'great'],
#  ['hall',
#   'and',
#   'the',
#   'scene',
#   'was',
#   'lit',
#   'b',
#   'the',
#   'warm',
#   'glow',
#   'of',
#   'the',
#   'setting',
#   'sun'],
#  ['at',
#   'first',
#   'things',
#   'were',
#   'ver',
#   'confusing',
#   'ever',
#   'thing',
#   'was',
#   'so',
#   'entirel'],
#  ['different',
#   'from',
#   'the',
#   'world',
#   'i',
#   'had',
#   'known',
#   'even',
#   'the',
#   'flowers',
#   'the',
#   'big'],
#  ['building',
#   'i',
#   'had',
#   'left',
#   'was',
#   'situated',
#   'on',
#   'the',
#   'slope',
#   'of',
#   'a',
#   'broad',
#   'river'],
#  ['valle',
#   'but',
#   'the',
#   'thames',
#   'had',
#   'shifted',
#   'perhaps',
#   'a',
#   'mile',
#   'from',
#   'its',
#   'present'],
#  ['position',
#   'i',
#   'resolved',
#   'to',
#   'mount',
#   'to',
#   'the',
#   'summit',
#   'of',
#   'a',
#   'crest',
#   'perhaps',
#   'a'],
#  ['mile',
#   'and',
#   'a',
#   'half',
#   'awa',
#   'from',
#   'which',
#   'i',
#   'could',
#   'get',
#   'a',
#   'wider',
#   'view',
#   'of',
#   'this'],
#  ['our',
#   'planet',
#   'in',
#   'the',
#   'ear',
#   'eight',
#   'hundred',
#   'and',
#   'two',
#   'thousand',
#   'seven',
#   'hundred'],
#  ['and',
#   'one',
#   'a',
#   'd',
#   'for',
#   'that',
#   'i',
#   'should',
#   'explain',
#   'was',
#   'the',
#   'date',
#   'the',
#   'little'],
#  ['dials', 'of', 'm', 'machine', 'recorded'],
#  [],
#  ['as',
#   'i',
#   'walked',
#   'i',
#   'was',
#   'watching',
#   'for',
#   'ever',
#   'impression',
#   'that',
#   'could',
#   'possibl'],
#  ['help',
#   'to',
#   'explain',
#   'the',
#   'condition',
#   'of',
#   'ruinous',
#   'splendour',
#   'in',
#   'which',
#   'i'],
#  ['found',
#   'the',
#   'world',
#   'for',
#   'ruinous',
#   'it',
#   'was',
#   'a',
#   'little',
#   'wa',
#   'up',
#   'the',
#   'hill',
#   'for'],
#  ['instance',
#   'was',
#   'a',
#   'great',
#   'heap',
#   'of',
#   'granite',
#   'bound',
#   'together',
#   'b',
#   'masses',
#   'of'],
#  ['aluminium',
#   'a',
#   'vast',
#   'lab',
#   'rinth',
#   'of',
#   'precipitous',
#   'walls',
#   'and',
#   'crumpled'],
#  ['heaps',
#   'amidst',
#   'which',
#   'were',
#   'thick',
#   'heaps',
#   'of',
#   'ver',
#   'beautiful',
#   'pagoda',
#   'like'],
#  ['plants',
#   'nettles',
#   'possibl',
#   'but',
#   'wonderfull',
#   'tinted',
#   'with',
#   'brown',
#   'about'],
#  ['the',
#   'leaves',
#   'and',
#   'incapable',
#   'of',
#   'stinging',
#   'it',
#   'was',
#   'evidentl',
#   'the',
#   'derelict'],
#  ['remains',
#   'of',
#   'some',
#   'vast',
#   'structure',
#   'to',
#   'what',
#   'end',
#   'built',
#   'i',
#   'could',
#   'not'],
#  ['determine',
#   'it',
#   'was',
#   'here',
#   'that',
#   'i',
#   'was',
#   'destined',
#   'at',
#   'a',
#   'later',
#   'date',
#   'to',
#   'have'],
#  ['a',
#   'ver',
#   'strange',
#   'experience',
#   'the',
#   'first',
#   'intimation',
#   'of',
#   'a',
#   'still',
#   'stranger'],
#  ['discover',
#   'but',
#   'of',
#   'that',
#   'i',
#   'will',
#   'speak',
#   'in',
#   'its',
#   'proper',
#   'place'],
#  [],
#  ['looking',
#   'round',
#   'with',
#   'a',
#   'sudden',
#   'thought',
#   'from',
#   'a',
#   'terrace',
#   'on',
#   'which',
#   'i'],
#  ['rested',
#   'for',
#   'a',
#   'while',
#   'i',
#   'reali',
#   'ed',
#   'that',
#   'there',
#   'were',
#   'no',
#   'small',
#   'houses',
#   'to',
#   'be'],
#  ['seen',
#   'apparentl',
#   'the',
#   'single',
#   'house',
#   'and',
#   'possibl',
#   'even',
#   'the',
#   'household'],
#  ['had',
#   'vanished',
#   'here',
#   'and',
#   'there',
#   'among',
#   'the',
#   'greener',
#   'were',
#   'palace',
#   'like'],
#  ['buildings',
#   'but',
#   'the',
#   'house',
#   'and',
#   'the',
#   'cottage',
#   'which',
#   'form',
#   'such'],
#  ['characteristic',
#   'features',
#   'of',
#   'our',
#   'own',
#   'english',
#   'landscape',
#   'had'],
#  ['disappeared'],
#  [],
#  ['communism', 'said', 'i', 'to', 'm', 'self'],
#  [],
#  ['and',
#   'on',
#   'the',
#   'heels',
#   'of',
#   'that',
#   'came',
#   'another',
#   'thought',
#   'i',
#   'looked',
#   'at',
#   'the'],
#  ['half',
#   'do',
#   'en',
#   'little',
#   'figures',
#   'that',
#   'were',
#   'following',
#   'me',
#   'then',
#   'in',
#   'a',
#   'flash'],
#  ['i',
#   'perceived',
#   'that',
#   'all',
#   'had',
#   'the',
#   'same',
#   'form',
#   'of',
#   'costume',
#   'the',
#   'same',
#   'soft'],
#  ['hairless',
#   'visage',
#   'and',
#   'the',
#   'same',
#   'girlish',
#   'rotundit',
#   'of',
#   'limb',
#   'it',
#   'ma',
#   'seem'],
#  ...]

# %% [markdown]
# 词元是string，而输入模型需要时数字；故构建词表（vocabulary）<br>
# 用来将string类型的词元映射为从0开始的数字索引中。<br>
# 先统计词元，得到语料（corpus）；然后根据词元出现频率为其分配数字索引<br>
# 删除很少出现的词元 以降低复杂性<br>
# 语料库中不存在或已删除的任何词元都将映射到一个特定的未知词元“< unk >”<br>
#     增加一个列表，用于保存那些被保留的词元， 例如：填充词元（“< pad>”）； 序列开始词元（“< bos>”）； 序列结束词元（“< eos>”）

# %%
tokens
# Out:
# [['the', 'time', 'machine', 'b', 'h', 'g', 'wells'],
#  [],
#  [],
#  [],
#  [],
#  ['i'],
#  [],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'for',
#   'so',
#   'it',
#   'will',
#   'be',
#   'convenient',
#   'to',
#   'speak',
#   'of',
#   'him'],
#  ['was',
#   'expounding',
#   'a',
#   'recondite',
#   'matter',
#   'to',
#   'us',
#   'his',
#   'gre',
#   'e',
#   'es',
#   'shone',
#   'and'],
#  ['twinkled',
#   'and',
#   'his',
#   'usuall',
#   'pale',
#   'face',
#   'was',
#   'flushed',
#   'and',
#   'animated',
#   'the'],
#  ['fire',
#   'burned',
#   'brightl',
#   'and',
#   'the',
#   'soft',
#   'radiance',
#   'of',
#   'the',
#   'incandescent'],
#  ['lights',
#   'in',
#   'the',
#   'lilies',
#   'of',
#   'silver',
#   'caught',
#   'the',
#   'bubbles',
#   'that',
#   'flashed',
#   'and'],
#  ['passed',
#   'in',
#   'our',
#   'glasses',
#   'our',
#   'chairs',
#   'being',
#   'his',
#   'patents',
#   'embraced',
#   'and'],
#  ['caressed',
#   'us',
#   'rather',
#   'than',
#   'submitted',
#   'to',
#   'be',
#   'sat',
#   'upon',
#   'and',
#   'there',
#   'was',
#   'that'],
#  ['luxurious',
#   'after',
#   'dinner',
#   'atmosphere',
#   'when',
#   'thought',
#   'roams',
#   'gracefull'],
#  ['free',
#   'of',
#   'the',
#   'trammels',
#   'of',
#   'precision',
#   'and',
#   'he',
#   'put',
#   'it',
#   'to',
#   'us',
#   'in',
#   'this'],
#  ['wa',
#   'marking',
#   'the',
#   'points',
#   'with',
#   'a',
#   'lean',
#   'forefinger',
#   'as',
#   'we',
#   'sat',
#   'and',
#   'la',
#   'il'],
#  ['admired',
#   'his',
#   'earnestness',
#   'over',
#   'this',
#   'new',
#   'paradox',
#   'as',
#   'we',
#   'thought',
#   'it'],
#  ['and', 'his', 'fecundit'],
#  [],
#  ['you',
#   'must',
#   'follow',
#   'me',
#   'carefull',
#   'i',
#   'shall',
#   'have',
#   'to',
#   'controvert',
#   'one',
#   'or',
#   'two'],
#  ['ideas',
#   'that',
#   'are',
#   'almost',
#   'universall',
#   'accepted',
#   'the',
#   'geometr',
#   'for'],
#  ['instance',
#   'the',
#   'taught',
#   'ou',
#   'at',
#   'school',
#   'is',
#   'founded',
#   'on',
#   'a',
#   'misconception'],
#  [],
#  ['is',
#   'not',
#   'that',
#   'rather',
#   'a',
#   'large',
#   'thing',
#   'to',
#   'expect',
#   'us',
#   'to',
#   'begin',
#   'upon'],
#  ['said', 'filb', 'an', 'argumentative', 'person', 'with', 'red', 'hair'],
#  [],
#  ['i',
#   'do',
#   'not',
#   'mean',
#   'to',
#   'ask',
#   'ou',
#   'to',
#   'accept',
#   'an',
#   'thing',
#   'without',
#   'reasonable'],
#  ['ground',
#   'for',
#   'it',
#   'you',
#   'will',
#   'soon',
#   'admit',
#   'as',
#   'much',
#   'as',
#   'i',
#   'need',
#   'from',
#   'ou',
#   'you'],
#  ['know',
#   'of',
#   'course',
#   'that',
#   'a',
#   'mathematical',
#   'line',
#   'a',
#   'line',
#   'of',
#   'thickness',
#   'nil'],
#  ['has',
#   'no',
#   'real',
#   'existence',
#   'the',
#   'taught',
#   'ou',
#   'that',
#   'neither',
#   'has',
#   'a'],
#  ['mathematical', 'plane', 'these', 'things', 'are', 'mere', 'abstractions'],
#  [],
#  ['that', 'is', 'all', 'right', 'said', 'the', 'ps', 'chologist'],
#  [],
#  ['nor',
#   'having',
#   'onl',
#   'length',
#   'breadth',
#   'and',
#   'thickness',
#   'can',
#   'a',
#   'cube',
#   'have',
#   'a'],
#  ['real', 'existence'],
#  [],
#  ['there',
#   'i',
#   'object',
#   'said',
#   'filb',
#   'of',
#   'course',
#   'a',
#   'solid',
#   'bod',
#   'ma',
#   'exist',
#   'all'],
#  ['real', 'things'],
#  [],
#  ['so',
#   'most',
#   'people',
#   'think',
#   'but',
#   'wait',
#   'a',
#   'moment',
#   'can',
#   'an',
#   'instantaneous'],
#  ['cube', 'exist'],
#  [],
#  ['don', 't', 'follow', 'ou', 'said', 'filb'],
#  [],
#  ['can',
#   'a',
#   'cube',
#   'that',
#   'does',
#   'not',
#   'last',
#   'for',
#   'an',
#   'time',
#   'at',
#   'all',
#   'have',
#   'a',
#   'real'],
#  ['existence'],
#  [],
#  ['filb',
#   'became',
#   'pensive',
#   'clearl',
#   'the',
#   'time',
#   'traveller',
#   'proceeded',
#   'an'],
#  ['real',
#   'bod',
#   'must',
#   'have',
#   'extension',
#   'in',
#   'four',
#   'directions',
#   'it',
#   'must',
#   'have'],
#  ['length',
#   'breadth',
#   'thickness',
#   'and',
#   'duration',
#   'but',
#   'through',
#   'a',
#   'natural'],
#  ['infirmit',
#   'of',
#   'the',
#   'flesh',
#   'which',
#   'i',
#   'will',
#   'explain',
#   'to',
#   'ou',
#   'in',
#   'a',
#   'moment',
#   'we'],
#  ['incline',
#   'to',
#   'overlook',
#   'this',
#   'fact',
#   'there',
#   'are',
#   'reall',
#   'four',
#   'dimensions'],
#  ['three',
#   'which',
#   'we',
#   'call',
#   'the',
#   'three',
#   'planes',
#   'of',
#   'space',
#   'and',
#   'a',
#   'fourth',
#   'time'],
#  ['there',
#   'is',
#   'however',
#   'a',
#   'tendenc',
#   'to',
#   'draw',
#   'an',
#   'unreal',
#   'distinction',
#   'between'],
#  ['the',
#   'former',
#   'three',
#   'dimensions',
#   'and',
#   'the',
#   'latter',
#   'because',
#   'it',
#   'happens',
#   'that'],
#  ['our',
#   'consciousness',
#   'moves',
#   'intermittentl',
#   'in',
#   'one',
#   'direction',
#   'along',
#   'the'],
#  ['latter',
#   'from',
#   'the',
#   'beginning',
#   'to',
#   'the',
#   'end',
#   'of',
#   'our',
#   'lives'],
#  [],
#  ['that',
#   'said',
#   'a',
#   'ver',
#   'oung',
#   'man',
#   'making',
#   'spasmodic',
#   'efforts',
#   'to',
#   'relight'],
#  ['his', 'cigar', 'over', 'the', 'lamp', 'that', 'ver', 'clear', 'indeed'],
#  [],
#  ['now',
#   'it',
#   'is',
#   'ver',
#   'remarkable',
#   'that',
#   'this',
#   'is',
#   'so',
#   'extensivel',
#   'overlooked'],
#  ['continued',
#   'the',
#   'time',
#   'traveller',
#   'with',
#   'a',
#   'slight',
#   'accession',
#   'of'],
#  ['cheerfulness',
#   'reall',
#   'this',
#   'is',
#   'what',
#   'is',
#   'meant',
#   'b',
#   'the',
#   'fourth',
#   'dimension'],
#  ['though',
#   'some',
#   'people',
#   'who',
#   'talk',
#   'about',
#   'the',
#   'fourth',
#   'dimension',
#   'do',
#   'not',
#   'know'],
#  ['the',
#   'mean',
#   'it',
#   'it',
#   'is',
#   'onl',
#   'another',
#   'wa',
#   'of',
#   'looking',
#   'at',
#   'time',
#   'there',
#   'is'],
#  ['no',
#   'difference',
#   'between',
#   'time',
#   'and',
#   'an',
#   'of',
#   'the',
#   'three',
#   'dimensions',
#   'of',
#   'space'],
#  ['except',
#   'that',
#   'our',
#   'consciousness',
#   'moves',
#   'along',
#   'it',
#   'but',
#   'some',
#   'foolish'],
#  ['people',
#   'have',
#   'got',
#   'hold',
#   'of',
#   'the',
#   'wrong',
#   'side',
#   'of',
#   'that',
#   'idea',
#   'you',
#   'have',
#   'all'],
#  ['heard',
#   'what',
#   'the',
#   'have',
#   'to',
#   'sa',
#   'about',
#   'this',
#   'fourth',
#   'dimension'],
#  [],
#  ['i', 'have', 'not', 'said', 'the', 'provincial', 'ma', 'or'],
#  [],
#  ['it',
#   'is',
#   'simpl',
#   'this',
#   'that',
#   'space',
#   'as',
#   'our',
#   'mathematicians',
#   'have',
#   'it',
#   'is'],
#  ['spoken',
#   'of',
#   'as',
#   'having',
#   'three',
#   'dimensions',
#   'which',
#   'one',
#   'ma',
#   'call',
#   'length'],
#  ['breadth',
#   'and',
#   'thickness',
#   'and',
#   'is',
#   'alwa',
#   's',
#   'definable',
#   'b',
#   'reference',
#   'to'],
#  ['three',
#   'planes',
#   'each',
#   'at',
#   'right',
#   'angles',
#   'to',
#   'the',
#   'others',
#   'but',
#   'some'],
#  ['philosophical',
#   'people',
#   'have',
#   'been',
#   'asking',
#   'wh',
#   'three',
#   'dimensions'],
#  ['particularl',
#   'wh',
#   'not',
#   'another',
#   'direction',
#   'at',
#   'right',
#   'angles',
#   'to',
#   'the',
#   'other'],
#  ['three',
#   'and',
#   'have',
#   'even',
#   'tried',
#   'to',
#   'construct',
#   'a',
#   'four',
#   'dimension',
#   'geometr'],
#  ['professor',
#   'simon',
#   'newcomb',
#   'was',
#   'expounding',
#   'this',
#   'to',
#   'the',
#   'new',
#   'york'],
#  ['mathematical',
#   'societ',
#   'onl',
#   'a',
#   'month',
#   'or',
#   'so',
#   'ago',
#   'you',
#   'know',
#   'how',
#   'on',
#   'a',
#   'flat'],
#  ['surface',
#   'which',
#   'has',
#   'onl',
#   'two',
#   'dimensions',
#   'we',
#   'can',
#   'represent',
#   'a',
#   'figure',
#   'of'],
#  ['a',
#   'three',
#   'dimensional',
#   'solid',
#   'and',
#   'similarl',
#   'the',
#   'think',
#   'that',
#   'b',
#   'models'],
#  ['of',
#   'three',
#   'dimensions',
#   'the',
#   'could',
#   'represent',
#   'one',
#   'of',
#   'four',
#   'if',
#   'the',
#   'could'],
#  ['master', 'the', 'perspective', 'of', 'the', 'thing', 'see'],
#  [],
#  ['i',
#   'think',
#   'so',
#   'murmured',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'and',
#   'knitting',
#   'his'],
#  ['brows',
#   'he',
#   'lapsed',
#   'into',
#   'an',
#   'introspective',
#   'state',
#   'his',
#   'lips',
#   'moving',
#   'as',
#   'one'],
#  ['who',
#   'repeats',
#   'm',
#   'stic',
#   'words',
#   'yes',
#   'i',
#   'think',
#   'i',
#   'see',
#   'it',
#   'now',
#   'he',
#   'said',
#   'after'],
#  ['some', 'time', 'brightening', 'in', 'a', 'quite', 'transitor', 'manner'],
#  [],
#  ['well',
#   'i',
#   'do',
#   'not',
#   'mind',
#   'telling',
#   'ou',
#   'i',
#   'have',
#   'been',
#   'at',
#   'work',
#   'upon',
#   'this'],
#  ['geometr',
#   'of',
#   'four',
#   'dimensions',
#   'for',
#   'some',
#   'time',
#   'some',
#   'of',
#   'm',
#   'results'],
#  ['are',
#   'curious',
#   'for',
#   'instance',
#   'here',
#   'is',
#   'a',
#   'portrait',
#   'of',
#   'a',
#   'man',
#   'at',
#   'eight'],
#  ['ears',
#   'old',
#   'another',
#   'at',
#   'fifteen',
#   'another',
#   'at',
#   'seventeen',
#   'another',
#   'at'],
#  ['twent',
#   'three',
#   'and',
#   'so',
#   'on',
#   'all',
#   'these',
#   'are',
#   'evidentl',
#   'sections',
#   'as',
#   'it'],
#  ['were',
#   'three',
#   'dimensional',
#   'representations',
#   'of',
#   'his',
#   'four',
#   'dimensioned'],
#  ['being', 'which', 'is', 'a', 'fixed', 'and', 'unalterable', 'thing'],
#  [],
#  ['scientific',
#   'people',
#   'proceeded',
#   'the',
#   'time',
#   'traveller',
#   'after',
#   'the',
#   'pause'],
#  ['required',
#   'for',
#   'the',
#   'proper',
#   'assimilation',
#   'of',
#   'this',
#   'know',
#   'ver',
#   'well',
#   'that'],
#  ['time',
#   'is',
#   'onl',
#   'a',
#   'kind',
#   'of',
#   'space',
#   'here',
#   'is',
#   'a',
#   'popular',
#   'scientific',
#   'diagram'],
#  ['a',
#   'weather',
#   'record',
#   'this',
#   'line',
#   'i',
#   'trace',
#   'with',
#   'm',
#   'finger',
#   'shows',
#   'the'],
#  ['movement',
#   'of',
#   'the',
#   'barometer',
#   'yesterda',
#   'it',
#   'was',
#   'so',
#   'high',
#   'esterda',
#   'night'],
#  ['it',
#   'fell',
#   'then',
#   'this',
#   'morning',
#   'it',
#   'rose',
#   'again',
#   'and',
#   'so',
#   'gentl',
#   'upward',
#   'to'],
#  ['here',
#   'surel',
#   'the',
#   'mercur',
#   'did',
#   'not',
#   'trace',
#   'this',
#   'line',
#   'in',
#   'an',
#   'of',
#   'the'],
#  ['dimensions',
#   'of',
#   'space',
#   'generall',
#   'recogni',
#   'ed',
#   'but',
#   'certainl',
#   'it',
#   'traced'],
#  ['such',
#   'a',
#   'line',
#   'and',
#   'that',
#   'line',
#   'therefore',
#   'we',
#   'must',
#   'conclude',
#   'was',
#   'along'],
#  ['the', 'time', 'dimension'],
#  [],
#  ['but',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'staring',
#   'hard',
#   'at',
#   'a',
#   'coal',
#   'in',
#   'the',
#   'fire',
#   'if'],
#  ['time',
#   'is',
#   'reall',
#   'onl',
#   'a',
#   'fourth',
#   'dimension',
#   'of',
#   'space',
#   'wh',
#   'is',
#   'it',
#   'and',
#   'wh'],
#  ['has',
#   'it',
#   'alwa',
#   's',
#   'been',
#   'regarded',
#   'as',
#   'something',
#   'different',
#   'and',
#   'wh',
#   'cannot'],
#  ['we',
#   'move',
#   'in',
#   'time',
#   'as',
#   'we',
#   'move',
#   'about',
#   'in',
#   'the',
#   'other',
#   'dimensions',
#   'of',
#   'space'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'smiled',
#   'are',
#   'ou',
#   'sure',
#   'we',
#   'can',
#   'move',
#   'freel',
#   'in'],
#  ['space',
#   'right',
#   'and',
#   'left',
#   'we',
#   'can',
#   'go',
#   'backward',
#   'and',
#   'forward',
#   'freel',
#   'enough'],
#  ['and',
#   'men',
#   'alwa',
#   's',
#   'have',
#   'done',
#   'so',
#   'i',
#   'admit',
#   'we',
#   'move',
#   'freel',
#   'in',
#   'two'],
#  ['dimensions',
#   'but',
#   'how',
#   'about',
#   'up',
#   'and',
#   'down',
#   'gravitation',
#   'limits',
#   'us',
#   'there'],
#  [],
#  ['not',
#   'exactl',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'there',
#   'are',
#   'balloons'],
#  [],
#  ['but',
#   'before',
#   'the',
#   'balloons',
#   'save',
#   'for',
#   'spasmodic',
#   'jumping',
#   'and',
#   'the'],
#  ['inequalities',
#   'of',
#   'the',
#   'surface',
#   'man',
#   'had',
#   'no',
#   'freedom',
#   'of',
#   'vertical'],
#  ['movement'],
#  [],
#  ['still',
#   'the',
#   'could',
#   'move',
#   'a',
#   'little',
#   'up',
#   'and',
#   'down',
#   'said',
#   'the',
#   'medical',
#   'man'],
#  [],
#  ['easier', 'far', 'easier', 'down', 'than', 'up'],
#  [],
#  ['and',
#   'ou',
#   'cannot',
#   'move',
#   'at',
#   'all',
#   'in',
#   'time',
#   'ou',
#   'cannot',
#   'get',
#   'awa',
#   'from',
#   'the'],
#  ['present', 'moment'],
#  [],
#  ['m',
#   'dear',
#   'sir',
#   'that',
#   'is',
#   'just',
#   'where',
#   'ou',
#   'are',
#   'wrong',
#   'that',
#   'is',
#   'just',
#   'where'],
#  ['the',
#   'whole',
#   'world',
#   'has',
#   'gone',
#   'wrong',
#   'we',
#   'are',
#   'alwa',
#   's',
#   'getting',
#   'awa',
#   'from',
#   'the'],
#  ['present',
#   'moment',
#   'our',
#   'mental',
#   'existences',
#   'which',
#   'are',
#   'immaterial',
#   'and',
#   'have'],
#  ['no',
#   'dimensions',
#   'are',
#   'passing',
#   'along',
#   'the',
#   'time',
#   'dimension',
#   'with',
#   'a',
#   'uniform'],
#  ['velocit',
#   'from',
#   'the',
#   'cradle',
#   'to',
#   'the',
#   'grave',
#   'just',
#   'as',
#   'we',
#   'should',
#   'travel',
#   'down'],
#  ['if',
#   'we',
#   'began',
#   'our',
#   'existence',
#   'fift',
#   'miles',
#   'above',
#   'the',
#   'earth',
#   's',
#   'surface'],
#  [],
#  ['but',
#   'the',
#   'great',
#   'difficult',
#   'is',
#   'this',
#   'interrupted',
#   'the',
#   'ps',
#   'chologist'],
#  ['you',
#   'can',
#   'move',
#   'about',
#   'in',
#   'all',
#   'directions',
#   'of',
#   'space',
#   'but',
#   'ou',
#   'cannot'],
#  ['move', 'about', 'in', 'time'],
#  [],
#  ['that',
#   'is',
#   'the',
#   'germ',
#   'of',
#   'm',
#   'great',
#   'discover',
#   'but',
#   'ou',
#   'are',
#   'wrong',
#   'to',
#   'sa'],
#  ['that',
#   'we',
#   'cannot',
#   'move',
#   'about',
#   'in',
#   'time',
#   'for',
#   'instance',
#   'if',
#   'i',
#   'am',
#   'recalling'],
#  ['an',
#   'incident',
#   'ver',
#   'vividl',
#   'i',
#   'go',
#   'back',
#   'to',
#   'the',
#   'instant',
#   'of',
#   'its',
#   'occurrence'],
#  ['i',
#   'become',
#   'absent',
#   'minded',
#   'as',
#   'ou',
#   'sa',
#   'i',
#   'jump',
#   'back',
#   'for',
#   'a',
#   'moment',
#   'of'],
#  ['course',
#   'we',
#   'have',
#   'no',
#   'means',
#   'of',
#   'sta',
#   'ing',
#   'back',
#   'for',
#   'an',
#   'length',
#   'of',
#   'time',
#   'an'],
#  ['more',
#   'than',
#   'a',
#   'savage',
#   'or',
#   'an',
#   'animal',
#   'has',
#   'of',
#   'sta',
#   'ing',
#   'six',
#   'feet',
#   'above',
#   'the'],
#  ['ground',
#   'but',
#   'a',
#   'civili',
#   'ed',
#   'man',
#   'is',
#   'better',
#   'off',
#   'than',
#   'the',
#   'savage',
#   'in',
#   'this'],
#  ['respect',
#   'he',
#   'can',
#   'go',
#   'up',
#   'against',
#   'gravitation',
#   'in',
#   'a',
#   'balloon',
#   'and',
#   'wh'],
#  ['should',
#   'he',
#   'not',
#   'hope',
#   'that',
#   'ultimatel',
#   'he',
#   'ma',
#   'be',
#   'able',
#   'to',
#   'stop',
#   'or'],
#  ['accelerate',
#   'his',
#   'drift',
#   'along',
#   'the',
#   'time',
#   'dimension',
#   'or',
#   'even',
#   'turn',
#   'about'],
#  ['and', 'travel', 'the', 'other', 'wa'],
#  [],
#  ['oh', 'this', 'began', 'filb', 'is', 'all'],
#  [],
#  ['wh', 'not', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['it', 's', 'against', 'reason', 'said', 'filb'],
#  [],
#  ['what', 'reason', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['you',
#   'can',
#   'show',
#   'black',
#   'is',
#   'white',
#   'b',
#   'argument',
#   'said',
#   'filb',
#   'but',
#   'ou',
#   'will'],
#  ['never', 'convince', 'me'],
#  [],
#  ['possibl',
#   'not',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'but',
#   'now',
#   'ou',
#   'begin',
#   'to',
#   'see'],
#  ['the',
#   'object',
#   'of',
#   'm',
#   'investigations',
#   'into',
#   'the',
#   'geometr',
#   'of',
#   'four'],
#  ['dimensions',
#   'long',
#   'ago',
#   'i',
#   'had',
#   'a',
#   'vague',
#   'inkling',
#   'of',
#   'a',
#   'machine'],
#  [],
#  ['to',
#   'travel',
#   'through',
#   'time',
#   'exclaimed',
#   'the',
#   'ver',
#   'young',
#   'man'],
#  [],
#  ['that',
#   'shall',
#   'travel',
#   'indifferentl',
#   'in',
#   'an',
#   'direction',
#   'of',
#   'space',
#   'and',
#   'time'],
#  ['as', 'the', 'driver', 'determines'],
#  [],
#  ['filb', 'contented', 'himself', 'with', 'laughter'],
#  [],
#  ['but',
#   'i',
#   'have',
#   'experimental',
#   'verification',
#   'said',
#   'the',
#   'time',
#   'traveller'],
#  [],
#  ['it',
#   'would',
#   'be',
#   'remarkabl',
#   'convenient',
#   'for',
#   'the',
#   'historian',
#   'the'],
#  ['ps',
#   'chologist',
#   'suggested',
#   'one',
#   'might',
#   'travel',
#   'back',
#   'and',
#   'verif',
#   'the'],
#  ['accepted',
#   'account',
#   'of',
#   'the',
#   'battle',
#   'of',
#   'hastings',
#   'for',
#   'instance'],
#  [],
#  ['don',
#   't',
#   'ou',
#   'think',
#   'ou',
#   'would',
#   'attract',
#   'attention',
#   'said',
#   'the',
#   'medical',
#   'man'],
#  ['our',
#   'ancestors',
#   'had',
#   'no',
#   'great',
#   'tolerance',
#   'for',
#   'anachronisms'],
#  [],
#  ['one',
#   'might',
#   'get',
#   'one',
#   's',
#   'greek',
#   'from',
#   'the',
#   'ver',
#   'lips',
#   'of',
#   'homer',
#   'and',
#   'plato'],
#  ['the', 'ver', 'young', 'man', 'thought'],
#  [],
#  ['in',
#   'which',
#   'case',
#   'the',
#   'would',
#   'certainl',
#   'plough',
#   'ou',
#   'for',
#   'the',
#   'little',
#   'go'],
#  ['the', 'german', 'scholars', 'have', 'improved', 'greek', 'so', 'much'],
#  [],
#  ['then',
#   'there',
#   'is',
#   'the',
#   'future',
#   'said',
#   'the',
#   'ver',
#   'young',
#   'man',
#   'just',
#   'think'],
#  ['one',
#   'might',
#   'invest',
#   'all',
#   'one',
#   's',
#   'mone',
#   'leave',
#   'it',
#   'to',
#   'accumulate',
#   'at'],
#  ['interest', 'and', 'hurr', 'on', 'ahead'],
#  [],
#  ['to',
#   'discover',
#   'a',
#   'societ',
#   'said',
#   'i',
#   'erected',
#   'on',
#   'a',
#   'strictl',
#   'communistic'],
#  ['basis'],
#  [],
#  ['of',
#   'all',
#   'the',
#   'wild',
#   'extravagant',
#   'theories',
#   'began',
#   'the',
#   'ps',
#   'chologist'],
#  [],
#  ['yes',
#   'so',
#   'it',
#   'seemed',
#   'to',
#   'me',
#   'and',
#   'so',
#   'i',
#   'never',
#   'talked',
#   'of',
#   'it',
#   'until'],
#  [],
#  ['experimental',
#   'verification',
#   'cried',
#   'i',
#   'you',
#   'are',
#   'going',
#   'to',
#   'verif'],
#  ['that'],
#  [],
#  ['the',
#   'experiment',
#   'cried',
#   'filb',
#   'who',
#   'was',
#   'getting',
#   'brain',
#   'wear'],
#  [],
#  ['let',
#   's',
#   'see',
#   'our',
#   'experiment',
#   'an',
#   'how',
#   'said',
#   'the',
#   'ps',
#   'chologist',
#   'though'],
#  ['it', 's', 'all', 'humbug', 'ou', 'know'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'smiled',
#   'round',
#   'at',
#   'us',
#   'then',
#   'still',
#   'smiling',
#   'faintl'],
#  ['and',
#   'with',
#   'his',
#   'hands',
#   'deep',
#   'in',
#   'his',
#   'trousers',
#   'pockets',
#   'he',
#   'walked',
#   'slowl'],
#  ['out',
#   'of',
#   'the',
#   'room',
#   'and',
#   'we',
#   'heard',
#   'his',
#   'slippers',
#   'shuffling',
#   'down',
#   'the',
#   'long'],
#  ['passage', 'to', 'his', 'laborator'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'looked',
#   'at',
#   'us',
#   'i',
#   'wonder',
#   'what',
#   'he',
#   's',
#   'got'],
#  [],
#  ['some',
#   'sleight',
#   'of',
#   'hand',
#   'trick',
#   'or',
#   'other',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'and'],
#  ['filb',
#   'tried',
#   'to',
#   'tell',
#   'us',
#   'about',
#   'a',
#   'conjurer',
#   'he',
#   'had',
#   'seen',
#   'at',
#   'burslem',
#   'but'],
#  ['before',
#   'he',
#   'had',
#   'finished',
#   'his',
#   'preface',
#   'the',
#   'time',
#   'traveller',
#   'came',
#   'back',
#   'and'],
#  ['filb', 's', 'anecdote', 'collapsed'],
#  [],
#  ['the',
#   'thing',
#   'the',
#   'time',
#   'traveller',
#   'held',
#   'in',
#   'his',
#   'hand',
#   'was',
#   'a',
#   'glittering'],
#  ['metallic',
#   'framework',
#   'scarcel',
#   'larger',
#   'than',
#   'a',
#   'small',
#   'clock',
#   'and',
#   'ver'],
#  ['delicatel',
#   'made',
#   'there',
#   'was',
#   'ivor',
#   'in',
#   'it',
#   'and',
#   'some',
#   'transparent'],
#  ['cr',
#   'stalline',
#   'substance',
#   'and',
#   'now',
#   'i',
#   'must',
#   'be',
#   'explicit',
#   'for',
#   'this',
#   'that'],
#  ['follows',
#   'unless',
#   'his',
#   'explanation',
#   'is',
#   'to',
#   'be',
#   'accepted',
#   'is',
#   'an',
#   'absolutel'],
#  ['unaccountable',
#   'thing',
#   'he',
#   'took',
#   'one',
#   'of',
#   'the',
#   'small',
#   'octagonal',
#   'tables',
#   'that'],
#  ['were',
#   'scattered',
#   'about',
#   'the',
#   'room',
#   'and',
#   'set',
#   'it',
#   'in',
#   'front',
#   'of',
#   'the',
#   'fire',
#   'with'],
#  ['two',
#   'legs',
#   'on',
#   'the',
#   'hearthrug',
#   'on',
#   'this',
#   'table',
#   'he',
#   'placed',
#   'the',
#   'mechanism'],
#  ['then',
#   'he',
#   'drew',
#   'up',
#   'a',
#   'chair',
#   'and',
#   'sat',
#   'down',
#   'the',
#   'onl',
#   'other',
#   'object',
#   'on',
#   'the'],
#  ['table',
#   'was',
#   'a',
#   'small',
#   'shaded',
#   'lamp',
#   'the',
#   'bright',
#   'light',
#   'of',
#   'which',
#   'fell',
#   'upon'],
#  ['the',
#   'model',
#   'there',
#   'were',
#   'also',
#   'perhaps',
#   'a',
#   'do',
#   'en',
#   'candles',
#   'about',
#   'two',
#   'in'],
#  ['brass',
#   'candlesticks',
#   'upon',
#   'the',
#   'mantel',
#   'and',
#   'several',
#   'in',
#   'sconces',
#   'so',
#   'that'],
#  ['the',
#   'room',
#   'was',
#   'brilliantl',
#   'illuminated',
#   'i',
#   'sat',
#   'in',
#   'a',
#   'low',
#   'arm',
#   'chair'],
#  ['nearest',
#   'the',
#   'fire',
#   'and',
#   'i',
#   'drew',
#   'this',
#   'forward',
#   'so',
#   'as',
#   'to',
#   'be',
#   'almost',
#   'between'],
#  ['the',
#   'time',
#   'traveller',
#   'and',
#   'the',
#   'fireplace',
#   'filb',
#   'sat',
#   'behind',
#   'him',
#   'looking'],
#  ['over',
#   'his',
#   'shoulder',
#   'the',
#   'medical',
#   'man',
#   'and',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'watched'],
#  ['him',
#   'in',
#   'profile',
#   'from',
#   'the',
#   'right',
#   'the',
#   'ps',
#   'chologist',
#   'from',
#   'the',
#   'left',
#   'the'],
#  ['ver',
#   'young',
#   'man',
#   'stood',
#   'behind',
#   'the',
#   'ps',
#   'chologist',
#   'we',
#   'were',
#   'all',
#   'on',
#   'the'],
#  ['alert',
#   'it',
#   'appears',
#   'incredible',
#   'to',
#   'me',
#   'that',
#   'an',
#   'kind',
#   'of',
#   'trick',
#   'however'],
#  ['subtl',
#   'conceived',
#   'and',
#   'however',
#   'adroitl',
#   'done',
#   'could',
#   'have',
#   'been',
#   'pla',
#   'ed'],
#  ['upon', 'us', 'under', 'these', 'conditions'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'looked',
#   'at',
#   'us',
#   'and',
#   'then',
#   'at',
#   'the',
#   'mechanism',
#   'well'],
#  ['said', 'the', 'ps', 'chologist'],
#  [],
#  ['this',
#   'little',
#   'affair',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'resting',
#   'his',
#   'elbows'],
#  ['upon',
#   'the',
#   'table',
#   'and',
#   'pressing',
#   'his',
#   'hands',
#   'together',
#   'above',
#   'the',
#   'apparatus'],
#  ['is',
#   'onl',
#   'a',
#   'model',
#   'it',
#   'is',
#   'm',
#   'plan',
#   'for',
#   'a',
#   'machine',
#   'to',
#   'travel',
#   'through'],
#  ['time',
#   'you',
#   'will',
#   'notice',
#   'that',
#   'it',
#   'looks',
#   'singularl',
#   'askew',
#   'and',
#   'that',
#   'there'],
#  ['is',
#   'an',
#   'odd',
#   'twinkling',
#   'appearance',
#   'about',
#   'this',
#   'bar',
#   'as',
#   'though',
#   'it',
#   'was',
#   'in'],
#  ['some',
#   'wa',
#   'unreal',
#   'he',
#   'pointed',
#   'to',
#   'the',
#   'part',
#   'with',
#   'his',
#   'finger',
#   'also'],
#  ['here',
#   'is',
#   'one',
#   'little',
#   'white',
#   'lever',
#   'and',
#   'here',
#   'is',
#   'another'],
#  [],
#  ['the',
#   'medical',
#   'man',
#   'got',
#   'up',
#   'out',
#   'of',
#   'his',
#   'chair',
#   'and',
#   'peered',
#   'into',
#   'the',
#   'thing'],
#  ['it', 's', 'beautifull', 'made', 'he', 'said'],
#  [],
#  ['it',
#   'took',
#   'two',
#   'ears',
#   'to',
#   'make',
#   'retorted',
#   'the',
#   'time',
#   'traveller',
#   'then',
#   'when'],
#  ['we',
#   'had',
#   'all',
#   'imitated',
#   'the',
#   'action',
#   'of',
#   'the',
#   'medical',
#   'man',
#   'he',
#   'said',
#   'now',
#   'i'],
#  ['want',
#   'ou',
#   'clearl',
#   'to',
#   'understand',
#   'that',
#   'this',
#   'lever',
#   'being',
#   'pressed',
#   'over'],
#  ['sends',
#   'the',
#   'machine',
#   'gliding',
#   'into',
#   'the',
#   'future',
#   'and',
#   'this',
#   'other',
#   'reverses'],
#  ['the',
#   'motion',
#   'this',
#   'saddle',
#   'represents',
#   'the',
#   'seat',
#   'of',
#   'a',
#   'time',
#   'traveller'],
#  ['presentl',
#   'i',
#   'am',
#   'going',
#   'to',
#   'press',
#   'the',
#   'lever',
#   'and',
#   'off',
#   'the',
#   'machine',
#   'will'],
#  ['go',
#   'it',
#   'will',
#   'vanish',
#   'pass',
#   'into',
#   'future',
#   'time',
#   'and',
#   'disappear',
#   'have',
#   'a'],
#  ['good',
#   'look',
#   'at',
#   'the',
#   'thing',
#   'look',
#   'at',
#   'the',
#   'table',
#   'too',
#   'and',
#   'satisf'],
#  ['ourselves',
#   'there',
#   'is',
#   'no',
#   'tricker',
#   'i',
#   'don',
#   't',
#   'want',
#   'to',
#   'waste',
#   'this',
#   'model'],
#  ['and', 'then', 'be', 'told', 'i', 'm', 'a', 'quack'],
#  [],
#  ['there',
#   'was',
#   'a',
#   'minute',
#   's',
#   'pause',
#   'perhaps',
#   'the',
#   'ps',
#   'chologist',
#   'seemed',
#   'about',
#   'to'],
#  ['speak',
#   'to',
#   'me',
#   'but',
#   'changed',
#   'his',
#   'mind',
#   'then',
#   'the',
#   'time',
#   'traveller',
#   'put',
#   'forth'],
#  ['his',
#   'finger',
#   'towards',
#   'the',
#   'lever',
#   'no',
#   'he',
#   'said',
#   'suddenl',
#   'lend',
#   'me',
#   'our'],
#  ['hand',
#   'and',
#   'turning',
#   'to',
#   'the',
#   'ps',
#   'chologist',
#   'he',
#   'took',
#   'that',
#   'individual',
#   's'],
#  ['hand',
#   'in',
#   'his',
#   'own',
#   'and',
#   'told',
#   'him',
#   'to',
#   'put',
#   'out',
#   'his',
#   'forefinger',
#   'so',
#   'that',
#   'it'],
#  ['was',
#   'the',
#   'ps',
#   'chologist',
#   'himself',
#   'who',
#   'sent',
#   'forth',
#   'the',
#   'model',
#   'time',
#   'machine'],
#  ['on',
#   'its',
#   'interminable',
#   'vo',
#   'age',
#   'we',
#   'all',
#   'saw',
#   'the',
#   'lever',
#   'turn',
#   'i',
#   'am'],
#  ['absolutel',
#   'certain',
#   'there',
#   'was',
#   'no',
#   'tricker',
#   'there',
#   'was',
#   'a',
#   'breath',
#   'of'],
#  ['wind',
#   'and',
#   'the',
#   'lamp',
#   'flame',
#   'jumped',
#   'one',
#   'of',
#   'the',
#   'candles',
#   'on',
#   'the',
#   'mantel'],
#  ['was',
#   'blown',
#   'out',
#   'and',
#   'the',
#   'little',
#   'machine',
#   'suddenl',
#   'swung',
#   'round',
#   'became'],
#  ['indistinct',
#   'was',
#   'seen',
#   'as',
#   'a',
#   'ghost',
#   'for',
#   'a',
#   'second',
#   'perhaps',
#   'as',
#   'an',
#   'edd',
#   'of'],
#  ['faintl',
#   'glittering',
#   'brass',
#   'and',
#   'ivor',
#   'and',
#   'it',
#   'was',
#   'gone',
#   'vanished',
#   'save'],
#  ['for', 'the', 'lamp', 'the', 'table', 'was', 'bare'],
#  [],
#  ['ever',
#   'one',
#   'was',
#   'silent',
#   'for',
#   'a',
#   'minute',
#   'then',
#   'filb',
#   'said',
#   'he',
#   'was',
#   'damned'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'recovered',
#   'from',
#   'his',
#   'stupor',
#   'and',
#   'suddenl',
#   'looked'],
#  ['under',
#   'the',
#   'table',
#   'at',
#   'that',
#   'the',
#   'time',
#   'traveller',
#   'laughed',
#   'cheerfull'],
#  ['well',
#   'he',
#   'said',
#   'with',
#   'a',
#   'reminiscence',
#   'of',
#   'the',
#   'ps',
#   'chologist',
#   'then'],
#  ['getting',
#   'up',
#   'he',
#   'went',
#   'to',
#   'the',
#   'tobacco',
#   'jar',
#   'on',
#   'the',
#   'mantel',
#   'and',
#   'with',
#   'his'],
#  ['back', 'to', 'us', 'began', 'to', 'fill', 'his', 'pipe'],
#  [],
#  ['we',
#   'stared',
#   'at',
#   'each',
#   'other',
#   'look',
#   'here',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'are',
#   'ou'],
#  ['in',
#   'earnest',
#   'about',
#   'this',
#   'do',
#   'ou',
#   'seriousl',
#   'believe',
#   'that',
#   'that',
#   'machine'],
#  ['has', 'travelled', 'into', 'time'],
#  [],
#  ['certainl',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'stooping',
#   'to',
#   'light',
#   'a',
#   'spill',
#   'at'],
#  ['the',
#   'fire',
#   'then',
#   'he',
#   'turned',
#   'lighting',
#   'his',
#   'pipe',
#   'to',
#   'look',
#   'at',
#   'the'],
#  ['ps',
#   'chologist',
#   's',
#   'face',
#   'the',
#   'ps',
#   'chologist',
#   'to',
#   'show',
#   'that',
#   'he',
#   'was',
#   'not'],
#  ['unhinged',
#   'helped',
#   'himself',
#   'to',
#   'a',
#   'cigar',
#   'and',
#   'tried',
#   'to',
#   'light',
#   'it',
#   'uncut'],
#  ['what',
#   'is',
#   'more',
#   'i',
#   'have',
#   'a',
#   'big',
#   'machine',
#   'nearl',
#   'finished',
#   'in',
#   'there',
#   'he'],
#  ['indicated',
#   'the',
#   'laborator',
#   'and',
#   'when',
#   'that',
#   'is',
#   'put',
#   'together',
#   'i',
#   'mean',
#   'to'],
#  ['have', 'a', 'journe', 'on', 'm', 'own', 'account'],
#  [],
#  ['you',
#   'mean',
#   'to',
#   'sa',
#   'that',
#   'that',
#   'machine',
#   'has',
#   'travelled',
#   'into',
#   'the',
#   'future'],
#  ['said', 'filb'],
#  [],
#  ['into',
#   'the',
#   'future',
#   'or',
#   'the',
#   'past',
#   'i',
#   'don',
#   't',
#   'for',
#   'certain',
#   'know',
#   'which'],
#  [],
#  ['after',
#   'an',
#   'interval',
#   'the',
#   'ps',
#   'chologist',
#   'had',
#   'an',
#   'inspiration',
#   'it',
#   'must',
#   'have'],
#  ['gone',
#   'into',
#   'the',
#   'past',
#   'if',
#   'it',
#   'has',
#   'gone',
#   'an',
#   'where',
#   'he',
#   'said'],
#  [],
#  ['wh', 'said', 'the', 'time', 'traveller'],
#  [],
#  ['because',
#   'i',
#   'presume',
#   'that',
#   'it',
#   'has',
#   'not',
#   'moved',
#   'in',
#   'space',
#   'and',
#   'if',
#   'it'],
#  ['travelled',
#   'into',
#   'the',
#   'future',
#   'it',
#   'would',
#   'still',
#   'be',
#   'here',
#   'all',
#   'this',
#   'time'],
#  ['since', 'it', 'must', 'have', 'travelled', 'through', 'this', 'time'],
#  [],
#  ['but',
#   'i',
#   'said',
#   'if',
#   'it',
#   'travelled',
#   'into',
#   'the',
#   'past',
#   'it',
#   'would',
#   'have',
#   'been'],
#  ['visible',
#   'when',
#   'we',
#   'came',
#   'first',
#   'into',
#   'this',
#   'room',
#   'and',
#   'last',
#   'thursda',
#   'when',
#   'we'],
#  ['were',
#   'here',
#   'and',
#   'the',
#   'thursda',
#   'before',
#   'that',
#   'and',
#   'so',
#   'forth'],
#  [],
#  ['serious',
#   'objections',
#   'remarked',
#   'the',
#   'provincial',
#   'ma',
#   'or',
#   'with',
#   'an',
#   'air',
#   'of'],
#  ['impartialit', 'turning', 'towards', 'the', 'time', 'traveller'],
#  [],
#  ['not',
#   'a',
#   'bit',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'and',
#   'to',
#   'the',
#   'ps',
#   'chologist',
#   'you'],
#  ['think',
#   'you',
#   'can',
#   'explain',
#   'that',
#   'it',
#   's',
#   'presentation',
#   'below',
#   'the',
#   'threshold'],
#  ['ou', 'know', 'diluted', 'presentation'],
#  [],
#  ['of',
#   'course',
#   'said',
#   'the',
#   'ps',
#   'chologist',
#   'and',
#   'reassured',
#   'us',
#   'that',
#   's',
#   'a'],
#  ['simple',
#   'point',
#   'of',
#   'ps',
#   'cholog',
#   'i',
#   'should',
#   'have',
#   'thought',
#   'of',
#   'it',
#   'it',
#   's',
#   'plain'],
#  ['enough',
#   'and',
#   'helps',
#   'the',
#   'paradox',
#   'delightfull',
#   'we',
#   'cannot',
#   'see',
#   'it',
#   'nor'],
#  ['can',
#   'we',
#   'appreciate',
#   'this',
#   'machine',
#   'an',
#   'more',
#   'than',
#   'we',
#   'can',
#   'the',
#   'spoke',
#   'of'],
#  ['a',
#   'wheel',
#   'spinning',
#   'or',
#   'a',
#   'bullet',
#   'fl',
#   'ing',
#   'through',
#   'the',
#   'air',
#   'if',
#   'it',
#   'is'],
#  ['travelling',
#   'through',
#   'time',
#   'fift',
#   'times',
#   'or',
#   'a',
#   'hundred',
#   'times',
#   'faster',
#   'than'],
#  ['we',
#   'are',
#   'if',
#   'it',
#   'gets',
#   'through',
#   'a',
#   'minute',
#   'while',
#   'we',
#   'get',
#   'through',
#   'a',
#   'second'],
#  ['the',
#   'impression',
#   'it',
#   'creates',
#   'will',
#   'of',
#   'course',
#   'be',
#   'onl',
#   'one',
#   'fiftieth',
#   'or'],
#  ['one',
#   'hundredth',
#   'of',
#   'what',
#   'it',
#   'would',
#   'make',
#   'if',
#   'it',
#   'were',
#   'not',
#   'travelling',
#   'in'],
#  ['time',
#   'that',
#   's',
#   'plain',
#   'enough',
#   'he',
#   'passed',
#   'his',
#   'hand',
#   'through',
#   'the',
#   'space',
#   'in'],
#  ['which',
#   'the',
#   'machine',
#   'had',
#   'been',
#   'you',
#   'see',
#   'he',
#   'said',
#   'laughing'],
#  [],
#  ['we',
#   'sat',
#   'and',
#   'stared',
#   'at',
#   'the',
#   'vacant',
#   'table',
#   'for',
#   'a',
#   'minute',
#   'or',
#   'so',
#   'then',
#   'the'],
#  ['time',
#   'traveller',
#   'asked',
#   'us',
#   'what',
#   'we',
#   'thought',
#   'of',
#   'it',
#   'all'],
#  [],
#  ['it',
#   'sounds',
#   'plausible',
#   'enough',
#   'to',
#   'night',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'but'],
#  ['wait',
#   'until',
#   'to',
#   'morrow',
#   'wait',
#   'for',
#   'the',
#   'common',
#   'sense',
#   'of',
#   'the',
#   'morning'],
#  [],
#  ['would',
#   'ou',
#   'like',
#   'to',
#   'see',
#   'the',
#   'time',
#   'machine',
#   'itself',
#   'asked',
#   'the',
#   'time'],
#  ['traveller',
#   'and',
#   'therewith',
#   'taking',
#   'the',
#   'lamp',
#   'in',
#   'his',
#   'hand',
#   'he',
#   'led',
#   'the'],
#  ['wa',
#   'down',
#   'the',
#   'long',
#   'draught',
#   'corridor',
#   'to',
#   'his',
#   'laborator',
#   'i',
#   'remember'],
#  ['vividl',
#   'the',
#   'flickering',
#   'light',
#   'his',
#   'queer',
#   'broad',
#   'head',
#   'in',
#   'silhouette'],
#  ['the',
#   'dance',
#   'of',
#   'the',
#   'shadows',
#   'how',
#   'we',
#   'all',
#   'followed',
#   'him',
#   'pu',
#   'led',
#   'but'],
#  ['incredulous',
#   'and',
#   'how',
#   'there',
#   'in',
#   'the',
#   'laborator',
#   'we',
#   'beheld',
#   'a',
#   'larger'],
#  ['edition',
#   'of',
#   'the',
#   'little',
#   'mechanism',
#   'which',
#   'we',
#   'had',
#   'seen',
#   'vanish',
#   'from',
#   'before'],
#  ['our',
#   'e',
#   'es',
#   'parts',
#   'were',
#   'of',
#   'nickel',
#   'parts',
#   'of',
#   'ivor',
#   'parts',
#   'had',
#   'certainl'],
#  ['been',
#   'filed',
#   'or',
#   'sawn',
#   'out',
#   'of',
#   'rock',
#   'cr',
#   'stal',
#   'the',
#   'thing',
#   'was',
#   'generall'],
#  ['complete',
#   'but',
#   'the',
#   'twisted',
#   'cr',
#   'stalline',
#   'bars',
#   'la',
#   'unfinished',
#   'upon',
#   'the'],
#  ['bench',
#   'beside',
#   'some',
#   'sheets',
#   'of',
#   'drawings',
#   'and',
#   'i',
#   'took',
#   'one',
#   'up',
#   'for',
#   'a',
#   'better'],
#  ['look', 'at', 'it', 'quart', 'it', 'seemed', 'to', 'be'],
#  [],
#  ['look',
#   'here',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'are',
#   'ou',
#   'perfectl',
#   'serious'],
#  ['or',
#   'is',
#   'this',
#   'a',
#   'trick',
#   'like',
#   'that',
#   'ghost',
#   'ou',
#   'showed',
#   'us',
#   'last',
#   'christmas'],
#  [],
#  ['upon',
#   'that',
#   'machine',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'holding',
#   'the',
#   'lamp'],
#  ['aloft',
#   'i',
#   'intend',
#   'to',
#   'explore',
#   'time',
#   'is',
#   'that',
#   'plain',
#   'i',
#   'was',
#   'never',
#   'more'],
#  ['serious', 'in', 'm', 'life'],
#  [],
#  ['none', 'of', 'us', 'quite', 'knew', 'how', 'to', 'take', 'it'],
#  [],
#  ['i',
#   'caught',
#   'filb',
#   's',
#   'e',
#   'e',
#   'over',
#   'the',
#   'shoulder',
#   'of',
#   'the',
#   'medical',
#   'man',
#   'and',
#   'he'],
#  ['winked', 'at', 'me', 'solemnl'],
#  [],
#  [],
#  [],
#  [],
#  ['ii'],
#  [],
#  [],
#  ['i',
#   'think',
#   'that',
#   'at',
#   'that',
#   'time',
#   'none',
#   'of',
#   'us',
#   'quite',
#   'believed',
#   'in',
#   'the',
#   'time'],
#  ['machine',
#   'the',
#   'fact',
#   'is',
#   'the',
#   'time',
#   'traveller',
#   'was',
#   'one',
#   'of',
#   'those',
#   'men',
#   'who'],
#  ['are',
#   'too',
#   'clever',
#   'to',
#   'be',
#   'believed',
#   'ou',
#   'never',
#   'felt',
#   'that',
#   'ou',
#   'saw',
#   'all',
#   'round'],
#  ['him',
#   'ou',
#   'alwa',
#   's',
#   'suspected',
#   'some',
#   'subtle',
#   'reserve',
#   'some',
#   'ingenuit',
#   'in'],
#  ['ambush',
#   'behind',
#   'his',
#   'lucid',
#   'frankness',
#   'had',
#   'filb',
#   'shown',
#   'the',
#   'model',
#   'and'],
#  ['explained',
#   'the',
#   'matter',
#   'in',
#   'the',
#   'time',
#   'traveller',
#   's',
#   'words',
#   'we',
#   'should',
#   'have'],
#  ['shown',
#   'him',
#   'far',
#   'less',
#   'scepticism',
#   'for',
#   'we',
#   'should',
#   'have',
#   'perceived',
#   'his'],
#  ['motives',
#   'a',
#   'pork',
#   'butcher',
#   'could',
#   'understand',
#   'filb',
#   'but',
#   'the',
#   'time'],
#  ['traveller',
#   'had',
#   'more',
#   'than',
#   'a',
#   'touch',
#   'of',
#   'whim',
#   'among',
#   'his',
#   'elements',
#   'and',
#   'we'],
#  ['distrusted',
#   'him',
#   'things',
#   'that',
#   'would',
#   'have',
#   'made',
#   'the',
#   'frame',
#   'of',
#   'a',
#   'less'],
#  ['clever',
#   'man',
#   'seemed',
#   'tricks',
#   'in',
#   'his',
#   'hands',
#   'it',
#   'is',
#   'a',
#   'mistake',
#   'to',
#   'do',
#   'things'],
#  ['too',
#   'easil',
#   'the',
#   'serious',
#   'people',
#   'who',
#   'took',
#   'him',
#   'seriousl',
#   'never',
#   'felt'],
#  ['quite',
#   'sure',
#   'of',
#   'his',
#   'deportment',
#   'the',
#   'were',
#   'somehow',
#   'aware',
#   'that',
#   'trusting'],
#  ['their',
#   'reputations',
#   'for',
#   'judgment',
#   'with',
#   'him',
#   'was',
#   'like',
#   'furnishing',
#   'a'],
#  ['nurser',
#   'with',
#   'egg',
#   'shell',
#   'china',
#   'so',
#   'i',
#   'don',
#   't',
#   'think',
#   'an',
#   'of',
#   'us',
#   'said',
#   'ver'],
#  ['much',
#   'about',
#   'time',
#   'travelling',
#   'in',
#   'the',
#   'interval',
#   'between',
#   'that',
#   'thursda',
#   'and'],
#  ['the',
#   'next',
#   'though',
#   'its',
#   'odd',
#   'potentialities',
#   'ran',
#   'no',
#   'doubt',
#   'in',
#   'most',
#   'of'],
#  ['our',
#   'minds',
#   'its',
#   'plausibilit',
#   'that',
#   'is',
#   'its',
#   'practical',
#   'incredibleness'],
#  ['the',
#   'curious',
#   'possibilities',
#   'of',
#   'anachronism',
#   'and',
#   'of',
#   'utter',
#   'confusion',
#   'it'],
#  ['suggested',
#   'for',
#   'm',
#   'own',
#   'part',
#   'i',
#   'was',
#   'particularl',
#   'preoccupied',
#   'with',
#   'the'],
#  ['trick',
#   'of',
#   'the',
#   'model',
#   'that',
#   'i',
#   'remember',
#   'discussing',
#   'with',
#   'the',
#   'medical',
#   'man'],
#  ['whom',
#   'i',
#   'met',
#   'on',
#   'frida',
#   'at',
#   'the',
#   'linnaean',
#   'he',
#   'said',
#   'he',
#   'had',
#   'seen',
#   'a',
#   'similar'],
#  ['thing',
#   'at',
#   'tubingen',
#   'and',
#   'laid',
#   'considerable',
#   'stress',
#   'on',
#   'the',
#   'blowing',
#   'out'],
#  ['of',
#   'the',
#   'candle',
#   'but',
#   'how',
#   'the',
#   'trick',
#   'was',
#   'done',
#   'he',
#   'could',
#   'not',
#   'explain'],
#  [],
#  ['the',
#   'next',
#   'thursda',
#   'i',
#   'went',
#   'again',
#   'to',
#   'richmond',
#   'i',
#   'suppose',
#   'i',
#   'was',
#   'one',
#   'of'],
#  ['the',
#   'time',
#   'traveller',
#   's',
#   'most',
#   'constant',
#   'guests',
#   'and',
#   'arriving',
#   'late',
#   'found'],
#  ['four',
#   'or',
#   'five',
#   'men',
#   'alread',
#   'assembled',
#   'in',
#   'his',
#   'drawing',
#   'room',
#   'the',
#   'medical'],
#  ['man',
#   'was',
#   'standing',
#   'before',
#   'the',
#   'fire',
#   'with',
#   'a',
#   'sheet',
#   'of',
#   'paper',
#   'in',
#   'one',
#   'hand'],
#  ['and',
#   'his',
#   'watch',
#   'in',
#   'the',
#   'other',
#   'i',
#   'looked',
#   'round',
#   'for',
#   'the',
#   'time',
#   'traveller'],
#  ['and',
#   'it',
#   's',
#   'half',
#   'past',
#   'seven',
#   'now',
#   'said',
#   'the',
#   'medical',
#   'man',
#   'i',
#   'suppose'],
#  ['we', 'd', 'better', 'have', 'dinner'],
#  [],
#  ['where', 's', 'said', 'i', 'naming', 'our', 'host'],
#  [],
#  ['you',
#   've',
#   'just',
#   'come',
#   'it',
#   's',
#   'rather',
#   'odd',
#   'he',
#   's',
#   'unavoidabl',
#   'detained',
#   'he'],
#  ['asks',
#   'me',
#   'in',
#   'this',
#   'note',
#   'to',
#   'lead',
#   'off',
#   'with',
#   'dinner',
#   'at',
#   'seven',
#   'if',
#   'he',
#   's',
#   'not'],
#  ['back', 'sa', 's', 'he', 'll', 'explain', 'when', 'he', 'comes'],
#  [],
#  ['it',
#   'seems',
#   'a',
#   'pit',
#   'to',
#   'let',
#   'the',
#   'dinner',
#   'spoil',
#   'said',
#   'the',
#   'editor',
#   'of',
#   'a'],
#  ['well',
#   'known',
#   'dail',
#   'paper',
#   'and',
#   'thereupon',
#   'the',
#   'doctor',
#   'rang',
#   'the',
#   'bell'],
#  [],
#  ['the',
#   'ps',
#   'chologist',
#   'was',
#   'the',
#   'onl',
#   'person',
#   'besides',
#   'the',
#   'doctor',
#   'and',
#   'm',
#   'self'],
#  ['who',
#   'had',
#   'attended',
#   'the',
#   'previous',
#   'dinner',
#   'the',
#   'other',
#   'men',
#   'were',
#   'blank',
#   'the'],
#  ['editor',
#   'aforementioned',
#   'a',
#   'certain',
#   'journalist',
#   'and',
#   'another',
#   'a',
#   'quiet'],
#  ['sh',
#   'man',
#   'with',
#   'a',
#   'beard',
#   'whom',
#   'i',
#   'didn',
#   't',
#   'know',
#   'and',
#   'who',
#   'as',
#   'far',
#   'as',
#   'm'],
#  ['observation',
#   'went',
#   'never',
#   'opened',
#   'his',
#   'mouth',
#   'all',
#   'the',
#   'evening',
#   'there',
#   'was'],
#  ['some',
#   'speculation',
#   'at',
#   'the',
#   'dinner',
#   'table',
#   'about',
#   'the',
#   'time',
#   'traveller',
#   's'],
#  ['absence',
#   'and',
#   'i',
#   'suggested',
#   'time',
#   'travelling',
#   'in',
#   'a',
#   'half',
#   'jocular',
#   'spirit'],
#  ['the',
#   'editor',
#   'wanted',
#   'that',
#   'explained',
#   'to',
#   'him',
#   'and',
#   'the',
#   'ps',
#   'chologist'],
#  ['volunteered',
#   'a',
#   'wooden',
#   'account',
#   'of',
#   'the',
#   'ingenious',
#   'paradox',
#   'and',
#   'trick',
#   'we'],
#  ['had',
#   'witnessed',
#   'that',
#   'da',
#   'week',
#   'he',
#   'was',
#   'in',
#   'the',
#   'midst',
#   'of',
#   'his',
#   'exposition'],
#  ['when',
#   'the',
#   'door',
#   'from',
#   'the',
#   'corridor',
#   'opened',
#   'slowl',
#   'and',
#   'without',
#   'noise',
#   'i'],
#  ['was',
#   'facing',
#   'the',
#   'door',
#   'and',
#   'saw',
#   'it',
#   'first',
#   'hallo',
#   'i',
#   'said',
#   'at',
#   'last'],
#  ['and',
#   'the',
#   'door',
#   'opened',
#   'wider',
#   'and',
#   'the',
#   'time',
#   'traveller',
#   'stood',
#   'before',
#   'us'],
#  ['i',
#   'gave',
#   'a',
#   'cr',
#   'of',
#   'surprise',
#   'good',
#   'heavens',
#   'man',
#   'what',
#   's',
#   'the',
#   'matter'],
#  ['cried',
#   'the',
#   'medical',
#   'man',
#   'who',
#   'saw',
#   'him',
#   'next',
#   'and',
#   'the',
#   'whole',
#   'tableful'],
#  ['turned', 'towards', 'the', 'door'],
#  [],
#  ['he',
#   'was',
#   'in',
#   'an',
#   'ama',
#   'ing',
#   'plight',
#   'his',
#   'coat',
#   'was',
#   'dust',
#   'and',
#   'dirt',
#   'and'],
#  ['smeared',
#   'with',
#   'green',
#   'down',
#   'the',
#   'sleeves',
#   'his',
#   'hair',
#   'disordered',
#   'and',
#   'as',
#   'it'],
#  ['seemed',
#   'to',
#   'me',
#   'gre',
#   'er',
#   'either',
#   'with',
#   'dust',
#   'and',
#   'dirt',
#   'or',
#   'because',
#   'its',
#   'colour'],
#  ['had',
#   'actuall',
#   'faded',
#   'his',
#   'face',
#   'was',
#   'ghastl',
#   'pale',
#   'his',
#   'chin',
#   'had',
#   'a',
#   'brown'],
#  ['cut',
#   'on',
#   'it',
#   'a',
#   'cut',
#   'half',
#   'healed',
#   'his',
#   'expression',
#   'was',
#   'haggard',
#   'and',
#   'drawn'],
#  ['as',
#   'b',
#   'intense',
#   'suffering',
#   'for',
#   'a',
#   'moment',
#   'he',
#   'hesitated',
#   'in',
#   'the',
#   'doorwa'],
#  ['as',
#   'if',
#   'he',
#   'had',
#   'been',
#   'da',
#   'led',
#   'b',
#   'the',
#   'light',
#   'then',
#   'he',
#   'came',
#   'into',
#   'the',
#   'room'],
#  ['he',
#   'walked',
#   'with',
#   'just',
#   'such',
#   'a',
#   'limp',
#   'as',
#   'i',
#   'have',
#   'seen',
#   'in',
#   'footsore',
#   'tramps'],
#  ['we',
#   'stared',
#   'at',
#   'him',
#   'in',
#   'silence',
#   'expecting',
#   'him',
#   'to',
#   'speak'],
#  [],
#  ['he',
#   'said',
#   'not',
#   'a',
#   'word',
#   'but',
#   'came',
#   'painfull',
#   'to',
#   'the',
#   'table',
#   'and',
#   'made',
#   'a'],
#  ['motion',
#   'towards',
#   'the',
#   'wine',
#   'the',
#   'editor',
#   'filled',
#   'a',
#   'glass',
#   'of',
#   'champagne',
#   'and'],
#  ['pushed',
#   'it',
#   'towards',
#   'him',
#   'he',
#   'drained',
#   'it',
#   'and',
#   'it',
#   'seemed',
#   'to',
#   'do',
#   'him',
#   'good'],
#  ['for',
#   'he',
#   'looked',
#   'round',
#   'the',
#   'table',
#   'and',
#   'the',
#   'ghost',
#   'of',
#   'his',
#   'old',
#   'smile'],
#  ['flickered',
#   'across',
#   'his',
#   'face',
#   'what',
#   'on',
#   'earth',
#   'have',
#   'ou',
#   'been',
#   'up',
#   'to',
#   'man'],
#  ['said',
#   'the',
#   'doctor',
#   'the',
#   'time',
#   'traveller',
#   'did',
#   'not',
#   'seem',
#   'to',
#   'hear',
#   'don',
#   't',
#   'let'],
#  ['me',
#   'disturb',
#   'ou',
#   'he',
#   'said',
#   'with',
#   'a',
#   'certain',
#   'faltering',
#   'articulation'],
#  ['i',
#   'm',
#   'all',
#   'right',
#   'he',
#   'stopped',
#   'held',
#   'out',
#   'his',
#   'glass',
#   'for',
#   'more',
#   'and',
#   'took'],
#  ['it',
#   'off',
#   'at',
#   'a',
#   'draught',
#   'that',
#   's',
#   'good',
#   'he',
#   'said',
#   'his',
#   'e',
#   'es',
#   'grew',
#   'brighter'],
#  ['and',
#   'a',
#   'faint',
#   'colour',
#   'came',
#   'into',
#   'his',
#   'cheeks',
#   'his',
#   'glance',
#   'flickered',
#   'over'],
#  ['our',
#   'faces',
#   'with',
#   'a',
#   'certain',
#   'dull',
#   'approval',
#   'and',
#   'then',
#   'went',
#   'round',
#   'the',
#   'warm'],
#  ['and',
#   'comfortable',
#   'room',
#   'then',
#   'he',
#   'spoke',
#   'again',
#   'still',
#   'as',
#   'it',
#   'were',
#   'feeling'],
#  ['his',
#   'wa',
#   'among',
#   'his',
#   'words',
#   'i',
#   'm',
#   'going',
#   'to',
#   'wash',
#   'and',
#   'dress',
#   'and',
#   'then',
#   'i',
#   'll'],
#  ['come',
#   'down',
#   'and',
#   'explain',
#   'things',
#   'save',
#   'me',
#   'some',
#   'of',
#   'that',
#   'mutton',
#   'i',
#   'm'],
#  ['starving', 'for', 'a', 'bit', 'of', 'meat'],
#  [],
#  ['he',
#   'looked',
#   'across',
#   'at',
#   'the',
#   'editor',
#   'who',
#   'was',
#   'a',
#   'rare',
#   'visitor',
#   'and',
#   'hoped',
#   'he'],
#  ['was',
#   'all',
#   'right',
#   'the',
#   'editor',
#   'began',
#   'a',
#   'question',
#   'tell',
#   'ou',
#   'presentl'],
#  ['said',
#   'the',
#   'time',
#   'traveller',
#   'i',
#   'm',
#   'funn',
#   'be',
#   'all',
#   'right',
#   'in',
#   'a',
#   'minute'],
#  [],
#  ['he',
#   'put',
#   'down',
#   'his',
#   'glass',
#   'and',
#   'walked',
#   'towards',
#   'the',
#   'staircase',
#   'door',
#   'again'],
#  ['i',
#   'remarked',
#   'his',
#   'lameness',
#   'and',
#   'the',
#   'soft',
#   'padding',
#   'sound',
#   'of',
#   'his',
#   'footfall'],
#  ['and',
#   'standing',
#   'up',
#   'in',
#   'm',
#   'place',
#   'i',
#   'saw',
#   'his',
#   'feet',
#   'as',
#   'he',
#   'went',
#   'out',
#   'he',
#   'had'],
#  ['nothing',
#   'on',
#   'them',
#   'but',
#   'a',
#   'pair',
#   'of',
#   'tattered',
#   'blood',
#   'stained',
#   'socks',
#   'then',
#   'the'],
#  ['door',
#   'closed',
#   'upon',
#   'him',
#   'i',
#   'had',
#   'half',
#   'a',
#   'mind',
#   'to',
#   'follow',
#   'till',
#   'i',
#   'remembered'],
#  ['how',
#   'he',
#   'detested',
#   'an',
#   'fuss',
#   'about',
#   'himself',
#   'for',
#   'a',
#   'minute',
#   'perhaps',
#   'm'],
#  ['mind',
#   'was',
#   'wool',
#   'gathering',
#   'then',
#   'remarkable',
#   'behaviour',
#   'of',
#   'an',
#   'eminent'],
#  ['scientist',
#   'i',
#   'heard',
#   'the',
#   'editor',
#   'sa',
#   'thinking',
#   'after',
#   'his',
#   'wont',
#   'in'],
#  ['headlines',
#   'and',
#   'this',
#   'brought',
#   'm',
#   'attention',
#   'back',
#   'to',
#   'the',
#   'bright'],
#  ['dinner', 'table'],
#  [],
#  ['what',
#   's',
#   'the',
#   'game',
#   'said',
#   'the',
#   'journalist',
#   'has',
#   'he',
#   'been',
#   'doing',
#   'the'],
#  ['amateur',
#   'cadger',
#   'i',
#   'don',
#   't',
#   'follow',
#   'i',
#   'met',
#   'the',
#   'e',
#   'e',
#   'of',
#   'the',
#   'ps',
#   'chologist'],
#  ['and',
#   'read',
#   'm',
#   'own',
#   'interpretation',
#   'in',
#   'his',
#   'face',
#   'i',
#   'thought',
#   'of',
#   'the',
#   'time'],
#  ['traveller',
#   'limping',
#   'painfull',
#   'upstairs',
#   'i',
#   'don',
#   't',
#   'think',
#   'an',
#   'one',
#   'else',
#   'had'],
#  ['noticed', 'his', 'lameness'],
#  [],
#  ['the',
#   'first',
#   'to',
#   'recover',
#   'completel',
#   'from',
#   'this',
#   'surprise',
#   'was',
#   'the',
#   'medical'],
#  ['man',
#   'who',
#   'rang',
#   'the',
#   'bell',
#   'the',
#   'time',
#   'traveller',
#   'hated',
#   'to',
#   'have',
#   'servants'],
#  ['waiting',
#   'at',
#   'dinner',
#   'for',
#   'a',
#   'hot',
#   'plate',
#   'at',
#   'that',
#   'the',
#   'editor',
#   'turned',
#   'to',
#   'his'],
#  ['knife',
#   'and',
#   'fork',
#   'with',
#   'a',
#   'grunt',
#   'and',
#   'the',
#   'silent',
#   'man',
#   'followed',
#   'suit',
#   'the'],
#  ['dinner',
#   'was',
#   'resumed',
#   'conversation',
#   'was',
#   'exclamator',
#   'for',
#   'a',
#   'little',
#   'while'],
#  ['with',
#   'gaps',
#   'of',
#   'wonderment',
#   'and',
#   'then',
#   'the',
#   'editor',
#   'got',
#   'fervent',
#   'in',
#   'his'],
#  ['curiosit',
#   'does',
#   'our',
#   'friend',
#   'eke',
#   'out',
#   'his',
#   'modest',
#   'income',
#   'with',
#   'a'],
#  ['crossing',
#   'or',
#   'has',
#   'he',
#   'his',
#   'nebuchadne',
#   'ar',
#   'phases',
#   'he',
#   'inquired',
#   'i',
#   'feel'],
#  ['assured',
#   'it',
#   's',
#   'this',
#   'business',
#   'of',
#   'the',
#   'time',
#   'machine',
#   'i',
#   'said',
#   'and',
#   'took',
#   'up'],
#  ['the',
#   'ps',
#   'chologist',
#   's',
#   'account',
#   'of',
#   'our',
#   'previous',
#   'meeting',
#   'the',
#   'new',
#   'guests'],
#  ['were',
#   'frankl',
#   'incredulous',
#   'the',
#   'editor',
#   'raised',
#   'objections',
#   'what',
#   'was'],
#  ['this',
#   'time',
#   'travelling',
#   'a',
#   'man',
#   'couldn',
#   't',
#   'cover',
#   'himself',
#   'with',
#   'dust',
#   'b'],
#  ['rolling',
#   'in',
#   'a',
#   'paradox',
#   'could',
#   'he',
#   'and',
#   'then',
#   'as',
#   'the',
#   'idea',
#   'came',
#   'home',
#   'to'],
#  ['him',
#   'he',
#   'resorted',
#   'to',
#   'caricature',
#   'hadn',
#   't',
#   'the',
#   'an',
#   'clothes',
#   'brushes',
#   'in'],
#  ['the',
#   'future',
#   'the',
#   'journalist',
#   'too',
#   'would',
#   'not',
#   'believe',
#   'at',
#   'an',
#   'price',
#   'and'],
#  ['joined',
#   'the',
#   'editor',
#   'in',
#   'the',
#   'eas',
#   'work',
#   'of',
#   'heaping',
#   'ridicule',
#   'on',
#   'the',
#   'whole'],
#  ['thing',
#   'the',
#   'were',
#   'both',
#   'the',
#   'new',
#   'kind',
#   'of',
#   'journalist',
#   'ver',
#   'jo',
#   'ous'],
#  ['irreverent',
#   'oung',
#   'men',
#   'our',
#   'special',
#   'correspondent',
#   'in',
#   'the',
#   'da'],
#  ['after',
#   'to',
#   'morrow',
#   'reports',
#   'the',
#   'journalist',
#   'was',
#   'sa',
#   'ing',
#   'or',
#   'rather'],
#  ['shouting',
#   'when',
#   'the',
#   'time',
#   'traveller',
#   'came',
#   'back',
#   'he',
#   'was',
#   'dressed',
#   'in'],
#  ['ordinar',
#   'evening',
#   'clothes',
#   'and',
#   'nothing',
#   'save',
#   'his',
#   'haggard',
#   'look',
#   'remained'],
#  ['of', 'the', 'change', 'that', 'had', 'startled', 'me'],
#  [],
#  ['i',
#   'sa',
#   'said',
#   'the',
#   'editor',
#   'hilariousl',
#   'these',
#   'chaps',
#   'here',
#   'sa',
#   'ou',
#   'have'],
#  ['been',
#   'travelling',
#   'into',
#   'the',
#   'middle',
#   'of',
#   'next',
#   'week',
#   'tell',
#   'us',
#   'all',
#   'about'],
#  ['little',
#   'roseber',
#   'will',
#   'ou',
#   'what',
#   'will',
#   'ou',
#   'take',
#   'for',
#   'the',
#   'lot'],
#  [],
#  ['the',
#   'time',
#   'traveller',
#   'came',
#   'to',
#   'the',
#   'place',
#   'reserved',
#   'for',
#   'him',
#   'without',
#   'a'],
#  ['word',
#   'he',
#   'smiled',
#   'quietl',
#   'in',
#   'his',
#   'old',
#   'wa',
#   'where',
#   's',
#   'm',
#   'mutton',
#   'he'],
#  ['said',
#   'what',
#   'a',
#   'treat',
#   'it',
#   'is',
#   'to',
#   'stick',
#   'a',
#   'fork',
#   'into',
#   'meat',
#   'again'],
#  [],
#  ['stor', 'cried', 'the', 'editor'],
#  [],
#  ['stor',
#   'be',
#   'damned',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'i',
#   'want',
#   'something',
#   'to'],
#  ['eat',
#   'i',
#   'won',
#   't',
#   'sa',
#   'a',
#   'word',
#   'until',
#   'i',
#   'get',
#   'some',
#   'peptone',
#   'into',
#   'm',
#   'arteries'],
#  ['thanks', 'and', 'the', 'salt'],
#  [],
#  ['one', 'word', 'said', 'i', 'have', 'ou', 'been', 'time', 'travelling'],
#  [],
#  ['yes',
#   'said',
#   'the',
#   'time',
#   'traveller',
#   'with',
#   'his',
#   'mouth',
#   'full',
#   'nodding',
#   'his'],
#  ['head'],
#  [],
#  ['i',
#   'd',
#   'give',
#   'a',
#   'shilling',
#   'a',
#   'line',
#   'for',
#   'a',
#   'verbatim',
#   'note',
#   'said',
#   'the',
#   'editor'],
#  ['the',
#   'time',
#   'traveller',
#   'pushed',
#   'his',
#   'glass',
#   'towards',
#   'the',
#   'silent',
#   'man',
#   'and',
#   'rang'],
#  ['it',
#   'with',
#   'his',
# ...
#   'you',
#   'who'],
#  ['have',
#   'never',
#   'seen',
#   'the',
#   'like',
#   'can',
#   'scarcel',
#   'imagine',
#   'what',
#   'delicate',
#   'and'],
#  ['wonderful',
#   'flowers',
#   'countless',
#   'ears',
#   'of',
#   'culture',
#   'had',
#   'created',
#   'then'],
#  ['someone',
#   'suggested',
#   'that',
#   'their',
#   'pla',
#   'thing',
#   'should',
#   'be',
#   'exhibited',
#   'in',
#   'the'],
#  ['nearest',
#   'building',
#   'and',
#   'so',
#   'i',
#   'was',
#   'led',
#   'past',
#   'the',
#   'sphinx',
#   'of',
#   'white',
#   'marble'],
#  ['which',
#   'had',
#   'seemed',
#   'to',
#   'watch',
#   'me',
#   'all',
#   'the',
#   'while',
#   'with',
#   'a',
#   'smile',
#   'at',
#   'm'],
#  ['astonishment',
#   'towards',
#   'a',
#   'vast',
#   'gre',
#   'edifice',
#   'of',
#   'fretted',
#   'stone',
#   'as',
#   'i'],
#  ['went',
#   'with',
#   'them',
#   'the',
#   'memor',
#   'of',
#   'm',
#   'confident',
#   'anticipations',
#   'of',
#   'a'],
#  ['profoundl',
#   'grave',
#   'and',
#   'intellectual',
#   'posterit',
#   'came',
#   'with',
#   'irresistible'],
#  ['merriment', 'to', 'm', 'mind'],
#  [],
#  ['the',
#   'building',
#   'had',
#   'a',
#   'huge',
#   'entr',
#   'and',
#   'was',
#   'altogether',
#   'of',
#   'colossal'],
#  ['dimensions',
#   'i',
#   'was',
#   'naturall',
#   'most',
#   'occupied',
#   'with',
#   'the',
#   'growing',
#   'crowd',
#   'of'],
#  ['little',
#   'people',
#   'and',
#   'with',
#   'the',
#   'big',
#   'open',
#   'portals',
#   'that',
#   'awned',
#   'before',
#   'me'],
#  ['shadow',
#   'and',
#   'm',
#   'sterious',
#   'm',
#   'general',
#   'impression',
#   'of',
#   'the',
#   'world',
#   'i',
#   'saw'],
#  ['over',
#   'their',
#   'heads',
#   'was',
#   'a',
#   'tangled',
#   'waste',
#   'of',
#   'beautiful',
#   'bushes',
#   'and'],
#  ['flowers',
#   'a',
#   'long',
#   'neglected',
#   'and',
#   'et',
#   'weedless',
#   'garden',
#   'i',
#   'saw',
#   'a',
#   'number'],
#  ['of',
#   'tall',
#   'spikes',
#   'of',
#   'strange',
#   'white',
#   'flowers',
#   'measuring',
#   'a',
#   'foot',
#   'perhaps'],
#  ['across',
#   'the',
#   'spread',
#   'of',
#   'the',
#   'waxen',
#   'petals',
#   'the',
#   'grew',
#   'scattered',
#   'as',
#   'if'],
#  ['wild',
#   'among',
#   'the',
#   'variegated',
#   'shrubs',
#   'but',
#   'as',
#   'i',
#   'sa',
#   'i',
#   'did',
#   'not',
#   'examine'],
#  ['them',
#   'closel',
#   'at',
#   'this',
#   'time',
#   'the',
#   'time',
#   'machine',
#   'was',
#   'left',
#   'deserted',
#   'on',
#   'the'],
#  ['turf', 'among', 'the', 'rhododendrons'],
#  [],
#  ['the',
#   'arch',
#   'of',
#   'the',
#   'doorwa',
#   'was',
#   'richl',
#   'carved',
#   'but',
#   'naturall',
#   'i',
#   'did'],
#  ['not',
#   'observe',
#   'the',
#   'carving',
#   'ver',
#   'narrowl',
#   'though',
#   'i',
#   'fancied',
#   'i',
#   'saw'],
#  ['suggestions',
#   'of',
#   'old',
#   'phoenician',
#   'decorations',
#   'as',
#   'i',
#   'passed',
#   'through',
#   'and'],
#  ['it',
#   'struck',
#   'me',
#   'that',
#   'the',
#   'were',
#   'ver',
#   'badl',
#   'broken',
#   'and',
#   'weather',
#   'worn'],
#  ['several',
#   'more',
#   'brightl',
#   'clad',
#   'people',
#   'met',
#   'me',
#   'in',
#   'the',
#   'doorwa',
#   'and',
#   'so',
#   'we'],
#  ['entered',
#   'i',
#   'dressed',
#   'in',
#   'ding',
#   'nineteenth',
#   'centur',
#   'garments',
#   'looking'],
#  ['grotesque',
#   'enough',
#   'garlanded',
#   'with',
#   'flowers',
#   'and',
#   'surrounded',
#   'b',
#   'an'],
#  ['edd',
#   'ing',
#   'mass',
#   'of',
#   'bright',
#   'soft',
#   'colored',
#   'robes',
#   'and',
#   'shining',
#   'white',
#   'limbs'],
#  ['in',
#   'a',
#   'melodious',
#   'whirl',
#   'of',
#   'laughter',
#   'and',
#   'laughing',
#   'speech'],
#  [],
#  ['the',
#   'big',
#   'doorwa',
#   'opened',
#   'into',
#   'a',
#   'proportionatel',
#   'great',
#   'hall',
#   'hung',
#   'with'],
#  ['brown',
#   'the',
#   'roof',
#   'was',
#   'in',
#   'shadow',
#   'and',
#   'the',
#   'windows',
#   'partiall',
#   'gla',
#   'ed'],
#  ['with',
#   'coloured',
#   'glass',
#   'and',
#   'partiall',
#   'ungla',
#   'ed',
#   'admitted',
#   'a',
#   'tempered'],
#  ['light',
#   'the',
#   'floor',
#   'was',
#   'made',
#   'up',
#   'of',
#   'huge',
#   'blocks',
#   'of',
#   'some',
#   'ver',
#   'hard',
#   'white'],
#  ['metal',
#   'not',
#   'plates',
#   'nor',
#   'slabs',
#   'blocks',
#   'and',
#   'it',
#   'was',
#   'so',
#   'much',
#   'worn',
#   'as',
#   'i'],
#  ['judged',
#   'b',
#   'the',
#   'going',
#   'to',
#   'and',
#   'fro',
#   'of',
#   'past',
#   'generations',
#   'as',
#   'to',
#   'be',
#   'deepl'],
#  ['channelled',
#   'along',
#   'the',
#   'more',
#   'frequented',
#   'wa',
#   's',
#   'transverse',
#   'to',
#   'the',
#   'length'],
#  ['were',
#   'innumerable',
#   'tables',
#   'made',
#   'of',
#   'slabs',
#   'of',
#   'polished',
#   'stone',
#   'raised'],
#  ['perhaps',
#   'a',
#   'foot',
#   'from',
#   'the',
#   'floor',
#   'and',
#   'upon',
#   'these',
#   'were',
#   'heaps',
#   'of',
#   'fruits'],
#  ['some',
#   'i',
#   'recogni',
#   'ed',
#   'as',
#   'a',
#   'kind',
#   'of',
#   'h',
#   'pertrophied',
#   'raspberr',
#   'and',
#   'orange'],
#  ['but', 'for', 'the', 'most', 'part', 'the', 'were', 'strange'],
#  [],
#  ['between',
#   'the',
#   'tables',
#   'was',
#   'scattered',
#   'a',
#   'great',
#   'number',
#   'of',
#   'cushions'],
#  ['upon',
#   'these',
#   'm',
#   'conductors',
#   'seated',
#   'themselves',
#   'signing',
#   'for',
#   'me',
#   'to',
#   'do'],
#  ['likewise',
#   'with',
#   'a',
#   'prett',
#   'absence',
#   'of',
#   'ceremon',
#   'the',
#   'began',
#   'to',
#   'eat',
#   'the'],
#  ['fruit',
#   'with',
#   'their',
#   'hands',
#   'flinging',
#   'peel',
#   'and',
#   'stalks',
#   'and',
#   'so',
#   'forth',
#   'into'],
#  ['the',
#   'round',
#   'openings',
#   'in',
#   'the',
#   'sides',
#   'of',
#   'the',
#   'tables',
#   'i',
#   'was',
#   'not',
#   'loath',
#   'to'],
#  ['follow',
#   'their',
#   'example',
#   'for',
#   'i',
#   'felt',
#   'thirst',
#   'and',
#   'hungr',
#   'as',
#   'i',
#   'did',
#   'so',
#   'i'],
#  ['surve', 'ed', 'the', 'hall', 'at', 'm', 'leisure'],
#  [],
#  ['and',
#   'perhaps',
#   'the',
#   'thing',
#   'that',
#   'struck',
#   'me',
#   'most',
#   'was',
#   'its',
#   'dilapidated',
#   'look'],
#  ['the',
#   'stained',
#   'glass',
#   'windows',
#   'which',
#   'displa',
#   'ed',
#   'onl',
#   'a',
#   'geometrical'],
#  ['pattern',
#   'were',
#   'broken',
#   'in',
#   'man',
#   'places',
#   'and',
#   'the',
#   'curtains',
#   'that',
#   'hung'],
#  ['across',
#   'the',
#   'lower',
#   'end',
#   'were',
#   'thick',
#   'with',
#   'dust',
#   'and',
#   'it',
#   'caught',
#   'm',
#   'e',
#   'e',
#   'that'],
#  ['the',
#   'corner',
#   'of',
#   'the',
#   'marble',
#   'table',
#   'near',
#   'me',
#   'was',
#   'fractured',
#   'nevertheless'],
#  ['the',
#   'general',
#   'effect',
#   'was',
#   'extremel',
#   'rich',
#   'and',
#   'picturesque',
#   'there',
#   'were'],
#  ['perhaps',
#   'a',
#   'couple',
#   'of',
#   'hundred',
#   'people',
#   'dining',
#   'in',
#   'the',
#   'hall',
#   'and',
#   'most',
#   'of'],
#  ['them',
#   'seated',
#   'as',
#   'near',
#   'to',
#   'me',
#   'as',
#   'the',
#   'could',
#   'come',
#   'were',
#   'watching',
#   'me',
#   'with'],
#  ['interest',
#   'their',
#   'little',
#   'e',
#   'es',
#   'shining',
#   'over',
#   'the',
#   'fruit',
#   'the',
#   'were',
#   'eating'],
#  ['all',
#   'were',
#   'clad',
#   'in',
#   'the',
#   'same',
#   'soft',
#   'and',
#   'et',
#   'strong',
#   'silk',
#   'material'],
#  [],
#  ['fruit',
#   'b',
#   'the',
#   'b',
#   'was',
#   'all',
#   'their',
#   'diet',
#   'these',
#   'people',
#   'of',
#   'the',
#   'remote'],
#  ['future',
#   'were',
#   'strict',
#   'vegetarians',
#   'and',
#   'while',
#   'i',
#   'was',
#   'with',
#   'them',
#   'in',
#   'spite'],
#  ['of',
#   'some',
#   'carnal',
#   'cravings',
#   'i',
#   'had',
#   'to',
#   'be',
#   'frugivorous',
#   'also',
#   'indeed',
#   'i'],
#  ['found',
#   'afterwards',
#   'that',
#   'horses',
#   'cattle',
#   'sheep',
#   'dogs',
#   'had',
#   'followed',
#   'the'],
#  ['ichth',
#   'osaurus',
#   'into',
#   'extinction',
#   'but',
#   'the',
#   'fruits',
#   'were',
#   'ver',
#   'delightful'],
#  ['one',
#   'in',
#   'particular',
#   'that',
#   'seemed',
#   'to',
#   'be',
#   'in',
#   'season',
#   'all',
#   'the',
#   'time',
#   'i',
#   'was'],
#  ['there',
#   'a',
#   'flour',
#   'thing',
#   'in',
#   'a',
#   'three',
#   'sided',
#   'husk',
#   'was',
#   'especiall',
#   'good'],
#  ['and',
#   'i',
#   'made',
#   'it',
#   'm',
#   'staple',
#   'at',
#   'first',
#   'i',
#   'was',
#   'pu',
#   'led',
#   'b',
#   'all',
#   'these',
#   'strange'],
#  ['fruits',
#   'and',
#   'b',
#   'the',
#   'strange',
#   'flowers',
#   'i',
#   'saw',
#   'but',
#   'later',
#   'i',
#   'began',
#   'to'],
#  ['perceive', 'their', 'import'],
#  [],
#  ['however',
#   'i',
#   'am',
#   'telling',
#   'ou',
#   'of',
#   'm',
#   'fruit',
#   'dinner',
#   'in',
#   'the',
#   'distant',
#   'future'],
#  ['now',
#   'so',
#   'soon',
#   'as',
#   'm',
#   'appetite',
#   'was',
#   'a',
#   'little',
#   'checked',
#   'i',
#   'determined',
#   'to'],
#  ['make',
#   'a',
#   'resolute',
#   'attempt',
#   'to',
#   'learn',
#   'the',
#   'speech',
#   'of',
#   'these',
#   'new',
#   'men',
#   'of'],
#  ['mine',
#   'clearl',
#   'that',
#   'was',
#   'the',
#   'next',
#   'thing',
#   'to',
#   'do',
#   'the',
#   'fruits',
#   'seemed',
#   'a'],
#  ['convenient',
#   'thing',
#   'to',
#   'begin',
#   'upon',
#   'and',
#   'holding',
#   'one',
#   'of',
#   'these',
#   'up',
#   'i',
#   'began'],
#  ['a',
#   'series',
#   'of',
#   'interrogative',
#   'sounds',
#   'and',
#   'gestures',
#   'i',
#   'had',
#   'some'],
#  ['considerable',
#   'difficult',
#   'in',
#   'conve',
#   'ing',
#   'm',
#   'meaning',
#   'at',
#   'first',
#   'm',
#   'efforts'],
#  ['met',
#   'with',
#   'a',
#   'stare',
#   'of',
#   'surprise',
#   'or',
#   'inextinguishable',
#   'laughter',
#   'but'],
#  ['presentl',
#   'a',
#   'fair',
#   'haired',
#   'little',
#   'creature',
#   'seemed',
#   'to',
#   'grasp',
#   'm',
#   'intention'],
#  ['and',
#   'repeated',
#   'a',
#   'name',
#   'the',
#   'had',
#   'to',
#   'chatter',
#   'and',
#   'explain',
#   'the',
#   'business'],
#  ['at',
#   'great',
#   'length',
#   'to',
#   'each',
#   'other',
#   'and',
#   'm',
#   'first',
#   'attempts',
#   'to',
#   'make',
#   'the'],
#  ['exquisite',
#   'little',
#   'sounds',
#   'of',
#   'their',
#   'language',
#   'caused',
#   'an',
#   'immense',
#   'amount'],
#  ['of',
#   'amusement',
#   'however',
#   'i',
#   'felt',
#   'like',
#   'a',
#   'schoolmaster',
#   'amidst',
#   'children'],
#  ['and',
#   'persisted',
#   'and',
#   'presentl',
#   'i',
#   'had',
#   'a',
#   'score',
#   'of',
#   'noun',
#   'substantives',
#   'at'],
#  ['least',
#   'at',
#   'm',
#   'command',
#   'and',
#   'then',
#   'i',
#   'got',
#   'to',
#   'demonstrative',
#   'pronouns',
#   'and'],
#  ['even',
#   'the',
#   'verb',
#   'to',
#   'eat',
#   'but',
#   'it',
#   'was',
#   'slow',
#   'work',
#   'and',
#   'the',
#   'little',
#   'people'],
#  ['soon',
#   'tired',
#   'and',
#   'wanted',
#   'to',
#   'get',
#   'awa',
#   'from',
#   'm',
#   'interrogations',
#   'so',
#   'i'],
#  ['determined',
#   'rather',
#   'of',
#   'necessit',
#   'to',
#   'let',
#   'them',
#   'give',
#   'their',
#   'lessons',
#   'in'],
#  ['little',
#   'doses',
#   'when',
#   'the',
#   'felt',
#   'inclined',
#   'and',
#   'ver',
#   'little',
#   'doses',
#   'i',
#   'found'],
#  ['the',
#   'were',
#   'before',
#   'long',
#   'for',
#   'i',
#   'never',
#   'met',
#   'people',
#   'more',
#   'indolent',
#   'or',
#   'more'],
#  ['easil', 'fatigued'],
#  [],
#  ['a',
#   'queer',
#   'thing',
#   'i',
#   'soon',
#   'discovered',
#   'about',
#   'm',
#   'little',
#   'hosts',
#   'and',
#   'that',
#   'was'],
#  ['their',
#   'lack',
#   'of',
#   'interest',
#   'the',
#   'would',
#   'come',
#   'to',
#   'me',
#   'with',
#   'eager',
#   'cries',
#   'of'],
#  ['astonishment',
#   'like',
#   'children',
#   'but',
#   'like',
#   'children',
#   'the',
#   'would',
#   'soon',
#   'stop'],
#  ['examining',
#   'me',
#   'and',
#   'wander',
#   'awa',
#   'after',
#   'some',
#   'other',
#   'to',
#   'the',
#   'dinner',
#   'and',
#   'm'],
#  ['conversational',
#   'beginnings',
#   'ended',
#   'i',
#   'noted',
#   'for',
#   'the',
#   'first',
#   'time',
#   'that'],
#  ['almost',
#   'all',
#   'those',
#   'who',
#   'had',
#   'surrounded',
#   'me',
#   'at',
#   'first',
#   'were',
#   'gone',
#   'it',
#   'is'],
#  ['odd',
#   'too',
#   'how',
#   'speedil',
#   'i',
#   'came',
#   'to',
#   'disregard',
#   'these',
#   'little',
#   'people',
#   'i'],
#  ['went',
#   'out',
#   'through',
#   'the',
#   'portal',
#   'into',
#   'the',
#   'sunlit',
#   'world',
#   'again',
#   'as',
#   'soon',
#   'as'],
#  ['m',
#   'hunger',
#   'was',
#   'satisfied',
#   'i',
#   'was',
#   'continuall',
#   'meeting',
#   'more',
#   'of',
#   'these',
#   'men'],
#  ['of',
#   'the',
#   'future',
#   'who',
#   'would',
#   'follow',
#   'me',
#   'a',
#   'little',
#   'distance',
#   'chatter',
#   'and'],
#  ['laugh',
#   'about',
#   'me',
#   'and',
#   'having',
#   'smiled',
#   'and',
#   'gesticulated',
#   'in',
#   'a',
#   'friendl'],
#  ['wa', 'leave', 'me', 'again', 'to', 'm', 'own', 'devices'],
#  [],
#  ['the',
#   'calm',
#   'of',
#   'evening',
#   'was',
#   'upon',
#   'the',
#   'world',
#   'as',
#   'i',
#   'emerged',
#   'from',
#   'the',
#   'great'],
#  ['hall',
#   'and',
#   'the',
#   'scene',
#   'was',
#   'lit',
#   'b',
#   'the',
#   'warm',
#   'glow',
#   'of',
#   'the',
#   'setting',
#   'sun'],
#  ['at',
#   'first',
#   'things',
#   'were',
#   'ver',
#   'confusing',
#   'ever',
#   'thing',
#   'was',
#   'so',
#   'entirel'],
#  ['different',
#   'from',
#   'the',
#   'world',
#   'i',
#   'had',
#   'known',
#   'even',
#   'the',
#   'flowers',
#   'the',
#   'big'],
#  ['building',
#   'i',
#   'had',
#   'left',
#   'was',
#   'situated',
#   'on',
#   'the',
#   'slope',
#   'of',
#   'a',
#   'broad',
#   'river'],
#  ['valle',
#   'but',
#   'the',
#   'thames',
#   'had',
#   'shifted',
#   'perhaps',
#   'a',
#   'mile',
#   'from',
#   'its',
#   'present'],
#  ['position',
#   'i',
#   'resolved',
#   'to',
#   'mount',
#   'to',
#   'the',
#   'summit',
#   'of',
#   'a',
#   'crest',
#   'perhaps',
#   'a'],
#  ['mile',
#   'and',
#   'a',
#   'half',
#   'awa',
#   'from',
#   'which',
#   'i',
#   'could',
#   'get',
#   'a',
#   'wider',
#   'view',
#   'of',
#   'this'],
#  ['our',
#   'planet',
#   'in',
#   'the',
#   'ear',
#   'eight',
#   'hundred',
#   'and',
#   'two',
#   'thousand',
#   'seven',
#   'hundred'],
#  ['and',
#   'one',
#   'a',
#   'd',
#   'for',
#   'that',
#   'i',
#   'should',
#   'explain',
#   'was',
#   'the',
#   'date',
#   'the',
#   'little'],
#  ['dials', 'of', 'm', 'machine', 'recorded'],
#  [],
#  ['as',
#   'i',
#   'walked',
#   'i',
#   'was',
#   'watching',
#   'for',
#   'ever',
#   'impression',
#   'that',
#   'could',
#   'possibl'],
#  ['help',
#   'to',
#   'explain',
#   'the',
#   'condition',
#   'of',
#   'ruinous',
#   'splendour',
#   'in',
#   'which',
#   'i'],
#  ['found',
#   'the',
#   'world',
#   'for',
#   'ruinous',
#   'it',
#   'was',
#   'a',
#   'little',
#   'wa',
#   'up',
#   'the',
#   'hill',
#   'for'],
#  ['instance',
#   'was',
#   'a',
#   'great',
#   'heap',
#   'of',
#   'granite',
#   'bound',
#   'together',
#   'b',
#   'masses',
#   'of'],
#  ['aluminium',
#   'a',
#   'vast',
#   'lab',
#   'rinth',
#   'of',
#   'precipitous',
#   'walls',
#   'and',
#   'crumpled'],
#  ['heaps',
#   'amidst',
#   'which',
#   'were',
#   'thick',
#   'heaps',
#   'of',
#   'ver',
#   'beautiful',
#   'pagoda',
#   'like'],
#  ['plants',
#   'nettles',
#   'possibl',
#   'but',
#   'wonderfull',
#   'tinted',
#   'with',
#   'brown',
#   'about'],
#  ['the',
#   'leaves',
#   'and',
#   'incapable',
#   'of',
#   'stinging',
#   'it',
#   'was',
#   'evidentl',
#   'the',
#   'derelict'],
#  ['remains',
#   'of',
#   'some',
#   'vast',
#   'structure',
#   'to',
#   'what',
#   'end',
#   'built',
#   'i',
#   'could',
#   'not'],
#  ['determine',
#   'it',
#   'was',
#   'here',
#   'that',
#   'i',
#   'was',
#   'destined',
#   'at',
#   'a',
#   'later',
#   'date',
#   'to',
#   'have'],
#  ['a',
#   'ver',
#   'strange',
#   'experience',
#   'the',
#   'first',
#   'intimation',
#   'of',
#   'a',
#   'still',
#   'stranger'],
#  ['discover',
#   'but',
#   'of',
#   'that',
#   'i',
#   'will',
#   'speak',
#   'in',
#   'its',
#   'proper',
#   'place'],
#  [],
#  ['looking',
#   'round',
#   'with',
#   'a',
#   'sudden',
#   'thought',
#   'from',
#   'a',
#   'terrace',
#   'on',
#   'which',
#   'i'],
#  ['rested',
#   'for',
#   'a',
#   'while',
#   'i',
#   'reali',
#   'ed',
#   'that',
#   'there',
#   'were',
#   'no',
#   'small',
#   'houses',
#   'to',
#   'be'],
#  ['seen',
#   'apparentl',
#   'the',
#   'single',
#   'house',
#   'and',
#   'possibl',
#   'even',
#   'the',
#   'household'],
#  ['had',
#   'vanished',
#   'here',
#   'and',
#   'there',
#   'among',
#   'the',
#   'greener',
#   'were',
#   'palace',
#   'like'],
#  ['buildings',
#   'but',
#   'the',
#   'house',
#   'and',
#   'the',
#   'cottage',
#   'which',
#   'form',
#   'such'],
#  ['characteristic',
#   'features',
#   'of',
#   'our',
#   'own',
#   'english',
#   'landscape',
#   'had'],
#  ['disappeared'],
#  [],
#  ['communism', 'said', 'i', 'to', 'm', 'self'],
#  [],
#  ['and',
#   'on',
#   'the',
#   'heels',
#   'of',
#   'that',
#   'came',
#   'another',
#   'thought',
#   'i',
#   'looked',
#   'at',
#   'the'],
#  ['half',
#   'do',
#   'en',
#   'little',
#   'figures',
#   'that',
#   'were',
#   'following',
#   'me',
#   'then',
#   'in',
#   'a',
#   'flash'],
#  ['i',
#   'perceived',
#   'that',
#   'all',
#   'had',
#   'the',
#   'same',
#   'form',
#   'of',
#   'costume',
#   'the',
#   'same',
#   'soft'],
#  ['hairless',
#   'visage',
#   'and',
#   'the',
#   'same',
#   'girlish',
#   'rotundit',
#   'of',
#   'limb',
#   'it',
#   'ma',
#   'seem'],
#  ...]

# %%
def count_corpus(tokens):
    # 统计词元频率
    if len(tokens) == 0 or isinstance(tokens[0], list):
        # 将二维词元展开成一维词元
        tokens = [token for line in tokens for token in line]
    return collections.Counter(tokens)

class Vocab:
    def __init__(self, tokens=None, min_freq=0, reserved_tokens=None) -> None:
        if tokens is None:
            tokens = []
        if reserved_tokens is None:
            reserved_tokens = []
        # 按出现频率排序
        counter = count_corpus(tokens)
        self._token_freqs = sorted(counter.items(), key=lambda x:x[1], reverse=True) # 对counter.items()第二维数据进行降序排序
        
        # 未知次词元引为0
        self.idx_to_token = ['unk'] + reserved_tokens
        self.token_to_idx = {token: idx for idx, token in enumerate(self.idx_to_token)}
        
        for token, freq in self.__token_freqs:
            if freq < min_freq:
                break
            if token not in self.token_to_idx:
                self.idx_to_token.append(token)
                self.token_to_idx[token] = len(self.idx_to_token) - 1 # 添加新词的索引
    
    def __len__(self):
        return len(self.idx_to_token)
    
    def __getitem__(self, tokens):
        if not isinstance(tokens, (list, tuple)):
            return self.token_to_idx.get(tokens, self.unk)
        return [self.__getitem__(token) for token in tokens]
    
    def to_tokens(self, indices):
        if not isinstance(indices, (list, tuple)):
            return self.idx_to_token[indices]
        return [self.idx_to_token[index] for index in indices]
